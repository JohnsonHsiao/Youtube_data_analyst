# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
import itertools
import warnings
warnings.filterwarnings("ignore")
import sys
import os
from pathlib import Path

user_home_path = str(Path.home())
sys.path.append(f"{user_home_path}/OrbitNext/api-data-download")


API_KEY_3 = 'AIzaSyC_G34pzth_j1dnilV93Dy1VnXCrEAbZqg'

youtube_builder = build('youtube', 'v3', developerKey=API_KEY_3)

example_channel = [
    ("UCBJycsmduvYEL83R_U4JriQ", "MKBHD"), 
    ("UCVYamHliCI9rw1tHR1xbkfw", "Dave2D"),
]

# %%
playist_id_df = pd.read_csv(f'{user_home_path}/OrbitNext/api-data-download/data_center/public_stats/playist_id/playist_id.csv')
playist_id_df = playist_id_df.loc[:, ~playist_id_df.columns.str.contains('^Unnamed')]

# %%
playist_id_df
# Out:
#        channel_name               playlist_id
# 0  Marques Brownlee  UUBJycsmduvYEL83R_U4JriQ
# 1            Dave2D  UUVYamHliCI9rw1tHR1xbkfw

# %%
len(playist_id_df)
# Out:
# 2

# %%
# func

def get_channel_stats(youtube_builder, channel_pool):

    requests = youtube_builder.channels().list(
        part = 'snippet, contentDetails, statistics',
        id = ','.join(channel_pool)
    )
    response = requests.execute()
    all_channel_data = []
    all_playlist_id_data = []
    all_description_data = []
    for i in range(len(response['items'])):
        # channel_data
        channel_data = dict(
            channel_name = response['items'][i]['snippet']['title'],
            subscribers = response['items'][i]['statistics']['subscriberCount'],
            view_count = response['items'][i]['statistics']['viewCount'],
            video_count = response['items'][i]['statistics']['videoCount'],
            playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'],
            etag =  response['items'][i]['etag'],
            publish_date = response['items'][i]['snippet']['publishedAt'],)
        
        # playlist_id_data
        playlist_id_data = dict(
            channel_name = response['items'][i]['snippet']['title'],
            playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        
        # description_data
        description_data = dict(
            channel_name = response['items'][i]['snippet']['title'],              
            description = response['items'][i]['snippet']['description'])
        
        all_channel_data.append(channel_data)
        all_channel_data = pd.DataFrame(all_channel_data)
        all_channel_data['subscribers'] = pd.to_numeric(all_channel_data['subscribers'])
        all_channel_data['view_count'] = pd.to_numeric(all_channel_data['view_count'])
        all_channel_data['publish_date'] = pd.to_datetime(all_channel_data['publish_date'])# maybe just need yy-mm-dd
        
        all_playlist_id_data.append(playlist_id_data)
        all_playlist_id_data = pd.DataFrame(all_playlist_id_data)
        
        all_description_data.append(description_data)
        all_description_data = pd.DataFrame(all_description_data)
        
    return all_channel_data, all_description_data, all_playlist_id_data


def get_video_ids(youtube, playlist_id):

    requests = youtube_builder.playlistItems().list(
        part = "contentDetails", 
        playlistId = playlist_id,
        maxResults = 50
    )
    response = requests.execute()
    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    next_page_token = response.get('nextPageToken')
    more_pages = True

    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            requests = youtube_builder.playlistItems().list(
                    part = "contentDetails", 
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token
                )
            response = requests.execute()

            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            next_page_token = response.get('nextPageToken')

    return video_ids

def get_video_details_in_json(youtube, video_ids):

    requests = youtube_builder.videos().list(
        part = 'snippet, statistics',
        id =  ','.join(video_ids[:50])
    )
    response = requests.execute()

    return response

def get_video_stats(youtube, video_ids):

    all_video_stats = []
    all_video_tag = []
    for i in range(0, len(video_ids), 50):
        requests = youtube_builder.videos().list(
            part = 'snippet, statistics',
            id = ','.join(video_ids[i:i+50])
        )
        response = requests.execute()
        for video in response['items']:
            video_stats = dict(
                title = video['snippet']['title'],
                published_date = video['snippet']['publishedAt'],
                channel_id = video['snippet']['channelId'],
                video_stats = video['statistics'], # first put it into 1 dict
                description = video['snippet']['description'],

#                 video_stats -> bug to-fix... shd work like below but dun know why...
#                 video_view_count = video['statistics']['viewCount'],
#                 video_like_count = video['statistics']['likeCount'],
#                 video_favorite_count = video['statistics']['favoriteCount'],
#                 video_comment_count = video['statistics']['commentCount'],
            )
            # tag shd also work??
            # video_tag = dict(tags = video["tags"])
            all_video_stats.append(video_stats)
            all_video_stats_df = pd.DataFrame(all_video_stats)
            all_video_stats_df['published_date'] = pd.to_datetime(all_video_stats_df['published_date']).dt.date

    return all_video_stats_df

# %%
# single youtuber example
mkbhd_video_ids = get_video_ids(youtube_builder, playlist_id='UUBJycsmduvYEL83R_U4JriQ')
mkbhd_video_ids
# Out:
# ['d7y9z7pjCRM',
#  'yQThMUn_UmM',
#  'MEiq0oCUb_8',
#  'JuWF9G6SSi0',
#  'ErMwWXQxHp0',
#  '4SHlY9AoXzc',
#  'AxV0_1Y4zl0',
#  'DFgYGBtJLnI',
#  'UsD87v8F914',
#  'HeMIZC2rkMo',
#  'Jb88eui8SqQ',
#  'WfVF-Ec4naQ',
#  'lYPe4MsALk4',
#  'dKq_xfCz3Jk',
#  'cCCBDhdcSGw',
#  'pSdKnNj7ozk',
#  'CkoquiSnqbk',
#  'mrkAmmMakMg',
#  'xcjZvAFBH_Y',
#  'MjGMeMrH73I',
#  '4U2ZxO7b8iM',
#  'MUU0BjJjAvk',
#  'yCBEumeXY4A',
#  '6CsJZxfZsL0',
#  'U3DNz5asasA',
#  'ZQ4E0JJcxz0',
#  '7jaMJGtAV9M',
#  'q72dA533sCg',
#  'MiTG1ride7s',
#  'dQrBgda0sEY',
#  '1Cw-vODp-8Y',
#  'YJGFjL7E3vU',
#  'a6zvvlrd-jw',
#  'UpqaQR4ikig',
#  'yoigsHYc77s',
#  'wvhP1al3Ur4',
#  'pwHNannxolo',
#  'QpbGctuHoMY',
#  'Y5iif7YskU4',
#  'CMm7UZKtGNk',
#  '-EZ_3Tq9a8c',
#  'bTYV7aFC6KE',
#  'vXIAB_1FEC0',
#  'qWIkBMNKj1s',
#  'k_OOiuaZSKc',
#  'ldadR6XqiWE',
#  'vax8FCuQUsE',
#  'L-BN9Db5QhY',
#  '7IaYSxDp88s',
#  'BuaKzm7Kq9Q',
#  '-njHjebtIg4',
#  '-pTGc7cIBIA',
#  'zV7y4Oex1DQ',
#  '0Jc5Ryk2mCw',
#  'n4xw2fmSCrs',
#  'fBHq7U8hLp8',
#  'IDcyXtweHCw',
#  'SOq05_6w0ig',
#  'dp4nWm59esI',
#  '_VAlGmtfDN0',
#  'MZ8giCWDcyE',
#  'gkmzDwgvqQM',
#  'JnGXTk57rOU',
#  '7nM6EaR50Tc',
#  '9l3f1KrMQeo',
#  'CaaJyRvvaq8',
#  '9rvqDxBsJX4',
#  'rr2XfL_df3o',
#  'LcI6F_GPwfE',
#  '9hvjBi4PKWA',
#  'A1uYhkMRLWg',
#  'y72bAm4SvkE',
#  'roWxo6jWoYw',
#  'uhIdijSrnVc',
#  'BsosQkfa2L8',
#  '8FpPSMIB4uA',
#  'vBnpGIZK9R0',
#  'TnkdoEZhTbc',
#  'gny4B5YOV0s',
#  'g5ymJNLURRI',
#  'T-UhbAcZd3I',
#  'Fop2oskTug8',
#  'ZvPzY6MsmCs',
#  'C4sAUc_ZGMY',
#  'TLQkoZX9Mog',
#  'vXzuFprlyrw',
#  '1uu9VWBgcBU',
#  'Wk1oClYJE58',
#  'iLLi02P1FN4',
#  'SG3Zz_pfbOE',
#  'SvMhWghZ_EE',
#  'ek9bmIlDens',
#  '7hEPj13PUGc',
#  'dbAkuiS8PHU',
#  '6E9cdgMvQT0',
#  'TranVlEwQqw',
#  'DyKQ7qtTJag',
#  'n3XrvrBVg2k',
#  'DDpXdljhstg',
#  'O1sZcX-BBSA',
#  'CghqH21A2Ew',
#  'U3JprndeVYU',
#  'VaSstf9VJGQ',
#  'ILHEYblJ7uM',
#  'FITTkh-kf6g',
#  'wGKb3oUo8go',
#  'ZS-LwWzlKdc',
#  'J2npVg9ONFo',
#  'n2RNcPRtAiY',
#  'eY9dXcjkVx8',
#  'vSAa_ls9grQ',
#  'RTbrXiIzUt4',
#  'qNAo0UdYF6g',
#  '07mIwEa3xbQ',
#  't7jbT1YhyQU',
#  'ehv3zQAa9zM',
#  'vInUoPtg8m0',
#  'ccnlAVDXd7k',
#  'MhKiMPiZOdE',
#  'nLeScEdf550',
#  'tEmLMCPK8OE',
#  'k_vD2S49INE',
#  'ifI_fwg55k8',
#  'R5_v0OdFD0A',
#  'wUqZQTp_gpI',
#  'cW1KJf7JKgI',
#  'CAmZXCZ-e94',
#  'TP4VQTUbypM',
#  'RY63Nw0w33w',
#  '8eNNJESKjrE',
#  'fYAUINqHAY4',
#  'syiQmaGZFXM',
#  '1jmcloqc4yg',
#  '6pf2KJD5qf0',
#  'V7J9aMy_CFk',
#  'di1afyrEKoc',
#  'qVMdq9pDiuQ',
#  'Sye31IVjiss',
#  '9zkFfBVgVtI',
#  'dhAmMXCBIcg',
#  'DHvkyrey3JE',
#  'vLm68qbNjkU',
#  'MXtbeSbf_xM',
#  'tn2AgrwXpNQ',
#  '_fqxMZi7P7U',
#  '1l0aosZHSDA',
#  'lvV3jSLYK8A',
#  'wUBy2W1iKpo',
#  '9EOAEWC9hJ4',
#  'mx3krJHlUzc',
#  'pJlA2J92Fw4',
#  'Lt-fah4spJY',
#  'e6_t26Q9aVM',
#  'I49VNQ6lmKk',
#  'Gvvo6vUpJRc',
#  '4oco9pLw13E',
#  'zrbACeJ63II',
#  'UdfSrJvqY_E',
#  'Qfmeb2e_kb4',
#  '6uS5F1MSzaQ',
#  'kbeEkwlTeqQ',
#  'il9SZU_nsVc',
#  'l4bNwGCx1FA',
#  'noKpc8fo-R0',
#  'f4g2nPY-VZc',
#  'MepGo2xmVJw',
#  'b7RhbRujjUA',
#  'b6g6rDDt9x8',
#  'qrzCLgDplTw',
#  'Yhze-aRR6o0',
#  'imx_-6tHjhw',
#  'eWI_BtcDJu0',
#  'QtMzV73NAgk',
#  'X1b3C2081-Q',
#  'NBLO6RpofIU',
#  'j5zvFXmSGKY',
#  'nDy32xoXM4o',
#  'Sx6dAx7dnXg',
#  't0XN-dJftSU',
#  'wjXIw6OjBo8',
#  'stsJe7pJaKU',
#  'VHt0LqGZVSY',
#  'k1v7_zScivQ',
#  'j7QwJ-M_GAI',
#  'XDamqi_3Aro',
#  'azrdcp4yYas',
#  'cH66LWWluVE',
#  'kFz9afj8lu0',
#  'BAZX9p2oGOg',
#  'UFDoLyAE1Bc',
#  'Mm0NvlXdz4A',
#  'eAagtcAup0o',
#  'G4E2bbAgjXg',
#  '0fB2cQFp008',
#  'qDSaOwBHwbs',
#  'sy8K2VmWkDo',
#  'DJyxwIGdl8Y',
#  'Exk34o-MMIE',
#  '9Hk_rvjtxKc',
#  'R94ntpWVelw',
#  '5NNO5Kb-PZo',
#  'bInJjmH31Hk',
#  's6_azdBnAlU',
#  '6kAvCSMkYEI',
#  'mRvBCXMSrBE',
#  'dlHnleQU9tQ',
#  'Xzh8BdaaAvs',
#  'j52nXdQKFD0',
#  'IEwEDTmqCEs',
#  'Svf1lEUUCzU',
#  'nF4hg6g7SwE',
#  'W-VInHvlrZo',
#  '5nLWTVTwOhY',
#  'bATUW8G2ONE',
#  '8IB7JcKJEeI',
#  'Q2aaCDNjWEg',
#  'ZLyDvABxGF0',
#  '0we7kcmgDOw',
#  'QZgIArBFmmE',
#  'JztgJT547Vg',
#  'gfC8Y66tR6o',
#  'pLjtItOE88s',
#  'g9McJA3XEF4',
#  '0FC94Tgz2ho',
#  'o-_WXXVye3Y',
#  'Ns8ydpZ5-4o',
#  'bfbyCTyHFo4',
#  '_SoviSNZjso',
#  'ByayqNQU2fA',
#  'u41Zt6z5s7A',
#  'wUhf0sWhtKw',
#  'mBHY_Qaw5AI',
#  'Kl0E8p2IBmw',
#  '48bK3mmjgRE',
#  'nxf41fMX_Y4',
#  'WIVUbBIrbM4',
#  'IUyrlM1qkGU',
#  'aXfiyuUziY0',
#  'eNWG9KRAbCc',
#  'UK8HH3_q4yI',
#  'OHP1rLwR6r8',
#  'LTDuGU38-70',
#  '3qtIp8joCE0',
#  '2xiCVNwhrDU',
#  'CF0Q4iozRIA',
#  'x_R-qzjZrKQ',
#  'koPg_DZUfOc',
#  'ASwVyfebu3E',
#  '58xXl597B_4',
#  'O8FJSjy3bXA',
#  '9arevpoH-4g',
#  '-wOdL7HFNOs',
#  'PTpoj4f25dk',
#  '7wZbsAzNt1o',
#  'NZzQQ1090wc',
#  'mx8ZDMb5MBg',
#  'dPaHNTnN0eE',
#  'FV2tMP37ygs',
#  'hiiVniW6l7E',
#  'WPsvw_Db-y4',
#  'ZdC9soHxVC8',
#  'lCKcFFDgtNk',
#  '-DtSrdh5dHU',
#  '7xtX1KNSlrY',
#  'zHAB4qDsgKY',
#  'pgmHkfvGYnY',
#  'x1T-VTFiUwc',
#  'Jp8bBZHDULA',
#  'NbzpwG4n6Vs',
#  'sr2fBCzXo4g',
#  '-2pffpPl1lQ',
#  'gl62BSjp7Vo',
#  '4OnwUz-I2GI',
#  'TfYeJZeCCjk',
#  '07_IZIoN60Q',
#  'NvQmi_ciL1k',
#  'KxsFat1ImiY',
#  '2SkaD7Q53mA',
#  'fLRRStkhcuQ',
#  'DOPswcaSsu8',
#  'jdlGvS1y_Ls',
#  'nmnTAOU44SI',
#  '-YFKqKdD3_A',
#  'kOEXcMoh2II',
#  '6oHrNuXPVck',
#  'AjQ7CEeONb4',
#  'PRVr1heimY8',
#  'VJI88QIW7H4',
#  'BsAmXFcQMQ4',
#  'kMtN9KJHn5Y',
#  'ctWDAdQ81B8',
#  'mXgG8k5tTFM',
#  'OX1xG0a4TVo',
#  'oTZ84U-K_5k',
#  'wegxoNTw0_I',
#  'UCv7qwuLpHs',
#  'uDAv4qOU_04',
#  'zIjngBAxTr4',
#  'cG8PXdTlDag',
#  'DHiKz_lCYMU',
#  'q2CdBFA98SI',
#  'MrUhzYdcX6w',
#  'mfbSqTB74xM',
#  'zsEcLVHnxUM',
#  'sKJ4i7p-o-4',
#  'JR4KHfqw-oE',
#  '5TuyvWoaAZk',
#  'O6NiridP0Oo',
#  'ux4R5GeKMUU',
#  'omyZvH7aMtg',
#  'aeaBaTqmu8Q',
#  'OoY7zp8GkLI',
#  'XRiUNPf-_-4',
#  'DyX-QZZBgpw',
#  'QK8Se8CvyHc',
#  '-5BsYYtyENw',
#  '-Wwe5OW_jPE',
#  '5krV47BLyoQ',
#  'UVpJouUyLBM',
#  'XoH8no1MQWA',
#  'gNK_C78sBWY',
#  'pyldH6sefTQ',
#  '0T0rop9pE58',
#  '_CTUs_2hq6Y',
#  'oZVLZDBLROs',
#  'lj7kFBz-jw4',
#  'qrwBeXBxaWU',
#  'WpPw7lUXyI0',
#  'ROkXM3csNWY',
#  'rie69P0W668',
#  'FOp3L2OTG6g',
#  'JqyzwbpYYqc',
#  'YPln3JP_gKs',
#  'dZ_Ab1XxxKg',
#  'JdTBIHX-r0M',
#  'MOJ1_FtDGNs',
#  'M5NVwuyk2uM',
#  '3Yes-qyeJ_M',
#  'O2iorLuSjOg',
#  'Wf1lQdupvPE',
#  'QJxbqIo5pC0',
#  'xjFPX7EoINs',
#  'ySMGudnpdXQ',
#  'XnSqlX1kCQo',
#  'qZGpmWrVSaU',
#  'JEWzl4V2YBI',
#  'jFZ0MFYup-o',
#  'PVWLD3064Ng',
#  'vcaXm9dgcpI',
#  'iDKIw3OgNcg',
#  '6C_4Bz62b0E',
#  'yiyjcXWZ3Qo',
#  'Oy8zSYKkczI',
#  'vtqtyyGZvXM',
#  'x4yF3a3Zn4Y',
#  '0Z8J3axc0oY',
#  'QKyul7puruQ',
#  'qSlDIpD8lD4',
#  'VL9rd4NLXCo',
#  '3AfpFkrS7Lw',
#  '-8oT3dE0hik',
#  '0O4_EAGNg7k',
#  'KzdLNlCXQSo',
#  'OQri1NdscR4',
#  'TI4PXFUOPR8',
#  'Lg8B4aTZf7o',
#  'ay8Ya0DYDYE',
#  'faUEM-szlnY',
#  'f5_Gvt3mOx8',
#  'hYIqILk4lbs',
#  't9R7xx0joOU',
#  'iy1z3ZVASCg',
#  'YFtxYb-GN9k',
#  'cZIso9uqNls',
#  '4mxXdCUXSSs',
#  'BSQe-yQ5B84',
#  'AnH7cm9Y7CE',
#  'I65jo06QinI',
#  'iLA1XLO8p1A',
#  '9ZjlFZ3_b9E',
#  'yz0Cr_nfNM4',
#  'gfWjsKsEry0',
#  'D1pa3UX89GA',
#  'ZX5ajIAhKTk',
#  'Q-0V9v-ybKU',
#  'wIdpm7cKtFc',
#  'zZ8NuPIymlk',
#  'HOh6d_r63Bw',
#  'cpIEWsQpRMk',
#  'MdqKJxyIecE',
#  'P5dxd-ocaE8',
#  'LPY4u9Gx-xM',
#  '_5-bo8a4zU0',
#  'Mbc_yzB8oAY',
#  'e7sw5xA066Y',
#  'nuNYtj8keaE',
#  '6w6pEXZutoY',
#  'N1e_voQvHYk',
#  'xsiV_-o5488',
#  '9fyI-SEnNl8',
#  'bNLgikGu4Yw',
#  'Fd7BrGUSxqQ',
#  '_6-XjSvbJsE',
#  'uwxxQ9FZXow',
#  'vc1NdYXlaxA',
#  'E67Klqw2H-E',
#  'ogdZT9yUVe0',
#  'Lg9N8XAZ6u4',
#  'pIuSElb3Ous',
#  'LRh_iVXulXk',
#  'aYoGMsImJhw',
#  'ndphYju6PVM',
#  'sb77YWaEsi8',
#  'naIaW4pk_-o',
#  'YAF9BWpzwvI',
#  'zHOr6Ej_jd4',
#  'mgOQgciWLlg',
#  'GSWOs4_etoE',
#  'ZVoaNzRo0uo',
#  'iCvlOrK_mag',
#  'QPcagFrOnLE',
#  'T8stUe9Vo74',
#  'wIaowvCQG1M',
#  'ihEhAbVRC78',
#  'mr9kK0_7x08',
#  'MevKTPN4ozw',
#  '9AxYQOX5_FM',
#  '0sXvuUrJa0o',
#  'oOaQVvNK4EU',
#  '5_5zZnuB71w',
#  'JF-Fkbm0XjU',
#  'cVCRAKDt21E',
#  'nIs8xAr_nIo',
#  'fwijCB6cH-0',
#  'fJ_PNOXycwg',
#  'E5jxF9uMgKo',
#  'r6axJnv3jpQ',
#  'i7FtVfokRYU',
#  'GRSfvePdhPA',
#  'sWeeGAj61dA',
#  'ThkMi9fkdEc',
#  '0NX9RjQClvg',
#  '9gkxwIZPOZk',
#  'RROs-zCrSko',
#  'nt9J_PynaOM',
#  'HxVLdhm2B6Y',
#  '0PrUr3bQdwM',
#  'oD_3wMh5kLg',
#  'F0rYqvRk9r8',
#  'bSl9PfRX7WY',
#  'XU69_u7eXa0',
#  'USXoINPEhoA',
#  'SGiOZnUQlEU',
#  'hvFbmImsCc4',
#  'OJfOsoUYPts',
#  'TQG7m1BFeRc',
#  'Er-hGFBcosc',
#  'TKGA7MhxPWc',
#  'MtUxFCicxuM',
#  '4O9dNuiOWDg',
#  'UIwdCN4dV6w',
#  'rsJlT53jU_4',
#  'Xyt9rmsxwDU',
#  'Gzy_nCkn88U',
#  '6AlzUeJ9zn0',
#  'xIvaQ1Hv2Ug',
#  'pqQrL1K0Z5g',
#  'KB4_WIPE7vo',
#  'jn9mHzXJIV0',
#  'ZzefeQ0v5wg',
#  'J83sZrz9XTc',
#  'DC-QGkKrxdM',
#  'dRtqFjYYUY0',
#  'mpjREfvZiDs',
#  'jmvacbha8e8',
#  'C-DfipidnOE',
#  'FjsQkOt553Q',
#  'sVdIWxa4dpA',
#  '9O5PhuW927w',
#  '6joCzIxiUaE',
#  'A4EKZRlpcIM',
#  '9GqohosViw4',
#  '-IqpbDJFbZA',
#  '6UR_H5XJkeM',
#  'Js3WIRF595U',
#  'fL30bWrGrfE',
#  'aMQbRpxgFvs',
#  'ZWuPwcwl214',
#  'h-h5Mhlt6O0',
#  'xhybjeRciYg',
#  '49-rK7SAfQk',
#  'Wzvr_rtI82w',
#  'ELo58FBl3R8',
#  '4L-BPQVZYXM',
#  'ctx4YBEdOxo',
#  'Lxet1zLBTM8',
#  '9Ca8zWJOlFQ',
#  'Ja_GMU7-sjs',
#  'AL_GHdjQ7-Y',
#  'NwN_uIWpNOQ',
#  'LzC_kkbFTHQ',
#  'l0DoQYGZt8M',
#  'c4guh00dOaQ',
#  'KvNis_A6UaI',
#  'ilyTQSn2zRo',
#  'a-9IZz8Ry5I',
#  'PgeJ0XYuI2E',
#  'wd9-VP2LzM8',
#  '2iObySa91b0',
#  'ld5H2L4j6LE',
#  'xig77hiUHig',
#  'TxNSSlk__x4',
#  'H1KRDYZIOaw',
#  'wQD1JvJZXdI',
#  'Q07Cp6tswnQ',
#  'm__4JVtUTCk',
#  '_HTXMhKWqnA',
#  'iOnNXJs6FUU',
#  'Ca8F3_olFvA',
#  'ftqaMBDj2oY',
#  'UeoeaDvhGvQ',
#  'XOoCGWk3y0s',
#  '-_WbmSxZnB8',
#  'hQZp6lp-3as',
#  'sdw_jquVZe0',
#  'r7ygnDKpFRE',
#  'BkpAro4zIwU',
#  'tQzqFbwWPSk',
#  'ywk2-xx0LP0',
#  'MgzwBW_LPdE',
#  'QnmpkMz69ZE',
#  'ZNAxkJL5OKU',
#  'ygMHYJEtk2c',
#  'l5nv86zjPro',
#  'uxxEjI27dwg',
#  'Wp-SqWal3VQ',
#  'W-YQr2HhORc',
#  'OkPter7MC1I',
#  '2BQ1rCqG19Y',
#  '2w5B1Ne-fy4',
#  '3Dl8wLo1W6E',
#  'z3X49SYvbo0',
#  'lENFECCD4ms',
#  'RvXmktAurSQ',
#  'dbWGjcHz9xA',
#  'oSnoYEzZnUg',
#  'A9ZvwOsLplU',
#  'ZPY7dIz0GBI',
#  'VEVWRGC0OJA',
#  'JBjCH8nRBYE',
#  'BfOLimMAhrs',
#  '6lCQqpvdgLQ',
#  'CnTuumKNvrI',
#  'DFKFnkP_sLQ',
#  'qfy6Bbro8GI',
#  'DtmGMcMeEJE',
#  'nNlTNE1y9DM',
#  '0n1x-wxESaM',
#  'n_SDw2LQ9N8',
#  '4DlNrCZFNGo',
#  'xfG15i_uQvc',
#  'Lm0QkWqMqHQ',
#  'Fz-6MdlPY1M',
#  'mJY-HhPcFhQ',
#  'zOMGY22XQs8',
#  'VDsjYTMyh94',
#  'Nq2Kum-eG8g',
#  '9VbD649W8EY',
#  'jbXEWi-OK4o',
#  'g-WWzf3wUik',
#  'HRgtHE9_3KU',
#  'X0ggW9mA22k',
#  '60OkiR1ujdg',
#  'f0NdOE5GTgo',
#  'xcSOGYqQ_kY',
#  'Vr3ya_uPmxg',
#  '5JdHSmaRiP4',
#  'J49hiExRUmQ',
#  'srj-NLj4Kt0',
#  'xXjQ6UoHs5U',
#  '9g2oMlstdwY',
#  'qtXZlpJP-Ik',
#  'M2VvFXCR3II',
#  'XIzimkcuEuk',
#  '67plwXQk6Ek',
#  'eFLTXiT5Rso',
#  'NKY93vCiPIo',
#  'QM5z0dW60KE',
#  'H3ZDtArXS6I',
#  'KftNp6hdO5g',
#  'DhCJuJoE6wM',
#  'Y6tzhAg0fQQ',
#  'C9Plog9I1JY',
#  '1cpUwbr5YyE',
#  'tXp-_3jvKsI',
#  'Snzshdl3hHI',
#  'KXr6ZNwWPXE',
#  '0f_BTRPUr6k',
#  'iuOslAj9-5A',
#  'LR708uA4zQ8',
#  '7q48xYdb8is',
#  '77aeW3bsCzc',
#  'WmHtebBGzjg',
#  'gWoqwCGQIM0',
#  'm7plA1ALkQw',
#  'JFiu5rfnhzo',
#  'iHwC92t2yQ4',
#  'mOwYlhUbsko',
#  'b-Bux7YrzxY',
#  'J8esUVOF-G4',
#  'xQLb_uwWzj8',
#  'XGFQOZ_owtc',
#  '-7q4lqhvlVQ',
#  'lV70CxFlx7w',
#  '-ICgMYIzhxg',
#  'XMAwwpYQd7E',
#  'J5HtSy5bATk',
#  'uVRcbo9_OdA',
#  '7TAPdmSuYBQ',
#  'BUsL-IxPquA',
#  'W82ErGmjUik',
#  '4l8eeqgCJnQ',
#  'ptni6tRrU54',
#  '0Ae0YwmgYTY',
#  'C2p5aREEWvk',
#  'ObDkWUm10OQ',
#  'yXYZQFTs8h0',
#  'OvyzimtwCdU',
#  'iaUW8Cn8fc0',
#  '2b1VPqCrk2c',
#  'AeuIE0gTYgg',
#  'DAxj9CjczXw',
#  'yD2iHEW09wk',
#  'ycIpOZY03OM',
#  'Hew1t8XZbPs',
#  'juzeLmUMjv0',
#  '96PJdbJysxQ',
#  'GiNSOLpC1-Y',
#  'mGojonPKBkY',
#  'ya7VlofjdwY',
#  'XVL0ybe18yI',
#  '9kiECQodMqE',
#  'amP7GVlUv2I',
#  'wsN6AHN2FbM',
#  'FBWvXZP_frg',
#  '5IJWckL5L84',
#  'K_34vZ9haCk',
#  'Tx_lyy4-SeY',
#  'ZvPxjhTOEgM',
#  'C-8Ux5ZQLLI',
#  '1sgeM6DsV40',
#  '8bMbcNUM68U',
#  'V2nPsyyme5I',
#  'RCgPD2sfbAQ',
#  'O6aSIa1sk6g',
#  '7SKRn_VNwNA',
#  'xdmuzyg50Vg',
#  'WmhKCq0vfjE',
#  'dU1YfSZDClE',
#  'itInMEcvjYc',
#  '2JlDVUcedbo',
#  'xCRjWur8-7c',
#  'gGrPigM0NeE',
#  'LeLi_Whav3I',
#  'QkcJL_FARp8',
#  '0hUxIO09hPA',
#  'C5UiAaeHdgg',
#  'vZLZtH5hnKo',
#  'X3DmlFkC2cI',
#  'ShcnNkr_PEY',
#  'UBuVR8_Mybw',
#  'h0BSqrfXBjM',
#  'dP5Au3tH448',
#  'AqkBD2FK7KE',
#  '-tuHrt42WnI',
#  '9TWB32376QA',
#  'fgK-bxZIG-o',
#  '9E006QLHt0Y',
#  'kEMmKu4tYWI',
#  'K-jYDRd_53w',
#  'XAoQPp9XLt8',
#  'ldS_yHnZMDs',
#  '0NTOZbjg6SE',
#  'YuHD9h5gTS4',
#  'zulLRv0GFhM',
#  'Xc5fFvp8le4',
#  'qv-RVkpQTWs',
#  '1K3iMWgAQzI',
#  'm1fUil7QLNI',
#  '2IIUHleexIk',
#  'cqybfPNbWBA',
#  'E357cGzOGLM',
#  'MQ9GDfE3BZg',
#  'gM_gTtll7FE',
#  '7jrmnPFlqG0',
#  'V-nBAcr_huw',
#  'HALtebWHpNA',
#  'gN-MeB-S8Kw',
#  'nL9Guwuv8HY',
#  'JWv3oRaZO9Y',
#  's8Un0XB_8xk',
#  'Nmkab1LUqlg',
#  'LObJOc5u7sY',
#  'q6kIwfEGLO4',
#  'Aq6RRmDExeI',
#  '9HDKRP4nzc0',
#  'cx20nTPZjes',
#  'cqLMQCG5pCs',
#  '91av8wCH7CI',
#  'xpc07Lbgrow',
#  'orPHNS-0CZI',
#  'VDiOv9148gc',
#  'XtLpZLM4jg0',
#  '5Nnu5Vdhwfs',
#  '9sTVbeq21dI',
#  'GkqI_2Fp9ok',
#  '6RskGkGYtgg',
#  'g0n2zT9xBdM',
#  'TA8JprZlDYA',
#  'VgmyVHYV1mE',
#  'UrzhzCA1NUw',
#  'XZvqQ4xK1R8',
#  'N3NPXB3eiPY',
#  'VTUDzrIgZlI',
#  '4CJvasYJP6o',
#  'dPL1-8ypnEs',
#  'Qfd8nck5cP4',
#  'Ws9KAQS02Yo',
#  'lpwa5iYOjU8',
#  'WjUebpBA2AE',
#  'Mhvv2-iCKao',
#  '4Q6kdHSWNZM',
#  '5x6DELO6Sz4',
#  'sBO5RKq8PXc',
#  'JDJDeuJbiKc',
#  'i4Zt3JZejbg',
#  '8syPkiANwYk',
#  'ZrZISyPucMg',
#  'GttoIyB_lEQ',
#  '2ircZoqveuA',
#  'QXF3tUfvuLU',
#  'TtLHiiXyERA',
#  'KrxrzzTUPD8',
#  'UUBDiUy2824',
#  '3yoAj-PRsZ0',
#  'KG9E5LaI8bk',
#  'UJ9Lbao6j-c',
#  'nnODX_VEp2c',
#  'aJinPXrOZYk',
#  '7hXjxLrDf5I',
#  '9nTJlmsa_Bo',
#  't8eKwFESN8s',
#  '_z9q096Lhj0',
#  'dIfLmM0YkXM',
#  'arlvHJnfFKI',
#  '26C_O6hDMjQ',
#  'CjYPLWcgAOE',
#  'Zh2wtbNrlyw',
#  'f6pPIG3EvAs',
#  'vE-P7zzCCsU',
#  'aEDJkbSJKP0',
#  'RoAPTdvgAJg',
#  'lMGggUDolRI',
#  'DqVPbEcWtA0',
#  'W-QoakKxTjg',
#  '7h-R73VTXXQ',
#  'YyrUBJQmUGs',
#  'pEDQ1z1-PvU',
#  'hoQKLOrAU4E',
#  'Wwp9eaVVW_8',
#  'opVgMDtBecA',
#  'iTLp2F4dm4I',
#  '61TAqY03xwk',
#  'wspZXjeWWq4',
#  'SlTvgY9PeCQ',
#  '3kYDVzwcwcg',
#  's3QcOSyD38M',
#  'XSf33i8njNU',
#  'BK3YvlOFRTg',
#  'X8DOUSGGw10',
#  'nxM-rac7vb4',
#  'uALVIcQXH4Q',
#  '8tU-0Uxz6jw',
#  'ZsxQxS0AdBY',
#  'EC00YntB7LQ',
#  'PNp2IjVv3HI',
#  '9HtGhNUtW-E',
#  'sFGEBTdK2Z0',
#  '2z9uOm-Ydrk',
#  'RUC_F0OQdDg',
#  '5BRVHKG_hpU',
#  'hgj1x0ecJMo',
#  'b7ANcWQEUI8',
#  '5R0_FJ4r73s',
#  'W8BfirN9z94',
#  'TmikWdsrz_U',
#  'y9ue7TNpxS0',
#  'U13DF7R-iuw',
#  'yBWNZTYPbzA',
#  '6trOg2IK2Zg',
#  '7QH1qFd24bY',
#  'BOOa1wZhkzY',
#  'yAyR_YHEZ_c',
#  'lXPvnhNcMs0',
#  'Btr8uOU0BkI',
#  'Ij9njxJUyUQ',
#  'd6605kiXmm8',
#  'AVpfhoi_uOM',
#  '2XvDb37qIdg',
#  'FrgGHAab9D8',
#  'NH_7FqSuxkU',
#  'EcMBuRX-EdU',
#  'c4zAPmQZmYA',
#  'R7siKvpvuCM',
#  'jzezFz6CMqg',
#  'Ew5ZzloH4Mg',
#  'QahWCPNALDA',
#  'z8gOX35dAfc',
#  'pwsPZi_JRrA',
#  'pmnLca3FneU',
#  'd7n34bkF-Ew',
#  'zSlt_2X8sPw',
#  'pZiKLNnanWs',
#  'VQW48jzIcjk',
#  'D0mCG1BeZCo',
#  'paENIboxKGI',
#  'lvNrGxpS2jY',
#  'fbwEaql90Ac',
#  'RwnSX-3ncSA',
#  'y5DyEYuvF3o',
#  'fKDuVDZqQ1c',
#  'r5TvTH3GOdc',
#  '8QF3qJ0U5K0',
#  'qauddPrHLqU',
#  'KBXTLLFgDeo',
#  'EtKa0ORwaU0',
#  'dYzlWWa8dCU',
#  'MVyA-T2lNNk',
#  '_ibTYAxssQw',
#  'szd7M-Qi1MI',
#  'tYGg1fIfuOY',
#  'BldsuTqsI1g',
#  'YGziBcgP93Y',
#  'M8rSmmLNYUc',
#  'L6RW1KaNuL0',
#  'dYmHFsH6E7g',
#  '8L7d6_ZzyoU',
#  'Rrm4isCQDkQ',
#  '8f7mFHYjBG0',
#  'BZjIsZwgKfo',
#  'E0_JrUNevdc',
#  'lVPAfntOfmc',
#  'tTfaaqXYXxQ',
#  'KFD0Nm2dOHw',
#  'kpqBNn_BfKE',
#  '3GrIWdORHvc',
#  'pMFLeoDx6J4',
#  '3AbWtn1ixVk',
#  'Z-W66HINFLg',
#  'tTxhneVcmEo',
#  'Hr8E-_yU2YA',
#  '1dg2UIzIt4s',
#  'RBCaAq_pKjY',
#  '1JEXDBWehvI',
#  'f7TD3Z03l2I',
#  'skXwTxo0Bo0',
#  'P4Hbn6xcD9M',
#  'hUgOgMCKXqs',
#  'z6dkNLn9br0',
#  'OMb-jXlkNwY',
#  'uBEaG6n0XDs',
#  'F0zhwl8454Y',
#  '9NSBB-kFDGQ',
#  'PYJAiY6zuMo',
#  'WBeFfWUdseI',
#  'uQyRDqnr0FM',
#  'IovZRv8toDM',
#  '6Smu8YbwZ9Q',
#  'fsOxwsFF50c',
#  'elXk87IKgCo',
#  '8yKXTr7KB40',
#  'Fi1JUykQBKw',
#  'lEjwyYOFwZg',
#  'h3wKBfAIdzE',
#  'CJTlB_S7ct0',
#  'wEpMtf6nJco',
#  '3ZX8graseUQ',
#  'wwXA27TWD3k',
#  'TK4u6wm-HIk',
#  'nei16gkVxpg',
#  'YmuOwOb35qs',
#  'TTWJq2MpCx4',
#  'fNt-QXLp6YI',
#  'CntfUc_Sd1c',
#  'tC1LxFS5uA4',
#  'saoiKoNvnn8',
#  'epLszn-rnpA',
#  'zb5Wp_i8oQo',
#  '4i3oKEg6o9g',
#  'QrM25jqhXdA',
#  'WxWLVwBqAOc',
#  'H9HH0vqb4q8',
#  'yR0ZGltMUTM',
#  'BygqMgC3W10',
#  'aYtAdCDOCfU',
#  'Cdbn_pmxFic',
#  'onldzSzdqlM',
#  'c74d5kqSEvo',
#  'ZWKl-FeUApA',
#  'jpiPzgBJU9M',
#  'KF75-HPdUfY',
#  'wXmzpFoHkfA',
#  '_bozaSWsDuE',
#  'rIRpK7KAfM0',
#  'swXI_sl5m3I',
#  'jZoh_QKnGbc',
#  'T88kUY9Q3es',
#  '1gUQhN5joSQ',
#  'LDBWrSENTps',
#  'Py6g_FheJWI',
#  'ul3lgaU_lbY',
#  'o9PT9HDXZWs',
#  'zUtedhbQDP4',
#  'PGXhG82HRX0',
#  'GlhXpHULwys',
#  'qp5il7yhM4Y',
#  '6d0lEMp8Vtk',
#  '83Y31z3ZI2A',
#  'CP5LB1eQff0',
#  'xU2fB0pQJkA',
#  'LkOC0gbNF20',
#  'MQ97Kymd6X0',
#  'uj0S2rgmu-M',
#  'XkqiFOvF8v0',
#  '6A-PpwfM1wo',
#  'Wm4jH01Sluc',
#  'N4fpYnzqHEM',
#  'Rd89JLYsoOI',
#  'K9CNsBCmrNg',
#  'mVLyd9_czWE',
#  '9qf3OmxwmhM',
#  'NSWOvw5N4nU',
#  'HVL6Kwk8IOA',
#  'SEXiPc3q1tg',
#  'tRyEYlvb66I',
#  'YginQUkrJ50',
#  'PAs6yQUCkno',
#  '8gca3uud87c',
#  '6PEmKUBtWlk',
#  'iwaW6HR9dw4',
#  'NyoM_i1jJZc',
#  'gfPNNdY1Fjs',
#  'FFuePFTf9LQ',
#  'uO0Q7SMZvfg',
#  'q1zZ8cGF1OI',
#  'IysmRC4aAFc',
#  'xVlzDdxaaaE',
#  'zFOnOLXrMBQ',
#  'bJOGQ_SJ8Dc',
#  'RvfjuYUe6-w',
#  'yRaIjn6q9Jo',
#  'nCVygTgQKUs',
#  'G43tYXIlUV4',
#  'RQy0NeVnxLo',
#  'Tqm8Izfn_oU',
#  'WeHC3qjt1Ws',
#  '7Tw9Yk-6jkQ',
#  'PPEpTasDz2s',
#  'y2d2tlnNYOg',
#  '2No-AEasdz8',
#  'GFdzwQw4CxQ',
#  'VdsMwGWvhO4',
#  'eFcpRIwPqRc',
#  'JpsTUT4F3BA',
#  '-gqjCVTXBeM',
#  'C-b9hmerTac',
#  'hKvoHRAYyMc',
#  'kRB1-APKUqs',
#  '1E6PDgIwFg4',
#  'aSZ2GogKawQ',
#  'Teyx-jx2Ano',
#  'MS3VXAUZcJE',
#  'APQqX8Xd5TA',
#  'IT73da-C4sw',
#  '3L27XnwKWkY',
#  '_02K6efDLI0',
#  '_hhEz4Uo79k',
#  'b_xRPA0CjJg',
#  'YddnWW_JYiY',
#  'bK959V_9XgQ',
#  'ddI-ZZwFclc',
#  'eG0As9lWP7I',
#  'nzikcaYKOkY',
#  'K7uLph0s6f0',
#  'kw-RzN4xYyE',
#  'poSFV9_abcw',
#  '4nKRZA4HVQg',
#  '4JEZ2rrf2N4',
#  'xAT0EmZc-LE',
#  'CultO7cPnJA',
#  ...]

# %%
# single youtuber example
get_video_stats(youtube_builder, mkbhd_video_ids)
# Out:
#                                                   title published_date  \
# 0                    The Hyundai IONIQ 5: I Get It Now!     2022-08-25
# 1                  Android 13 Hands-On: Top 5 Features!     2022-08-16
# 2           Dope Tech: The Most Extreme Gaming Monitor!     2022-08-15
# 3     Samsung Z Fold 4/ Flip 4 Impressions + Watch 5...     2022-08-10
# 4                        Best Back to School Tech 2022!     2022-08-08
# ...                                                 ...            ...
# 1455                    Fraps HD Test in 1080p (18 WOS)     2009-01-01
# 1456      HP Pavilion dv7t Media Center Remote Overview     2009-01-01
# 1457                        High fps LG Voyager footage     2008-09-16
# 1458              14 Year knock-down shot (11 Handicap)     2008-05-30
# 1459                    13-Year-Old Golf Swing Analysis     2008-03-29
#
#                     channel_id  \
# 0     UCBJycsmduvYEL83R_U4JriQ
# 1     UCBJycsmduvYEL83R_U4JriQ
# 2     UCBJycsmduvYEL83R_U4JriQ
# 3     UCBJycsmduvYEL83R_U4JriQ
# 4     UCBJycsmduvYEL83R_U4JriQ
# ...                        ...
# 1455  UCBJycsmduvYEL83R_U4JriQ
# 1456  UCBJycsmduvYEL83R_U4JriQ
# 1457  UCBJycsmduvYEL83R_U4JriQ
# 1458  UCBJycsmduvYEL83R_U4JriQ
# 1459  UCBJycsmduvYEL83R_U4JriQ
#
#                                             video_stats  \
# 0     {'viewCount': '1430410', 'likeCount': '72582',...
# 1     {'viewCount': '2961712', 'likeCount': '137452'...
# 2     {'viewCount': '2428473', 'likeCount': '119859'...
# 3     {'viewCount': '3166866', 'likeCount': '128356'...
# 4     {'viewCount': '1887820', 'likeCount': '97581',...
# ...                                                 ...
# 1455  {'viewCount': '133973', 'likeCount': '1636', '...
# 1456  {'viewCount': '4686155', 'likeCount': '235834'...
# 1457  {'viewCount': '185229', 'likeCount': '2732', '...
# 1458  {'viewCount': '179988', 'likeCount': '2288', '...
# 1459  {'viewCount': '809805', 'likeCount': '18198', ...
#
#                                             description
# 0     If the future of cars is electric, we need mor...
# 1     The 5 best features in the newest Android 13 U...
# 2     Dope Tech is back! Transparent batteries, mass...
# 3     A hands-on with Samsung's new Z Fold 4, Z Flip...
# 4     Thanks to @Best Buy for sponsoring today's vid...
# ...                                                 ...
# 1455  ***WATCH IN HD***\r\n\r\nAlso, check out my vi...
# 1456  This is my short review of the Media Center Re...
# 1457  This video was uploaded directly from my LG Vo...
# 1458  Me hitting a knock-down shot with a six iron, ...
# 1459  A breif vid of me hitting about a 240-yard dra...
#
# [1460 rows x 5 columns]

# %% [markdown]
# #### let try all channel in example pool

# %%
# correct

all_videoId = []
for playlist_id in playist_id_df['playlist_id']:
    video_ids = get_video_ids(youtube_builder, playlist_id=playlist_id)
    all_videoId.append(video_ids)

# %%
len(all_videoId) # we use 2 youtuber as example
# Out:
# 2

# %%
all_videoId_df = pd.DataFrame(all_videoId)
all_videoId_df.T

# dataframe might not be a good idea...
# Out:
#                 0            1
# 0     d7y9z7pjCRM  nhOnLlshf60
# 1     yQThMUn_UmM  QEo7b36mOcM
# 2     MEiq0oCUb_8  BnXRS18K7gc
# 3     JuWF9G6SSi0  fu_M9EmP_gk
# 4     ErMwWXQxHp0  J_0teOgTAhQ
# ...           ...          ...
# 1455  hCEBLSSU-2Y         None
# 1456  9gk_rl3y_SU         None
# 1457  f7mqssf66l4         None
# 1458  PD5igzFB8iY         None
# 1459  fjhmnWFsr3s         None
#
# [1460 rows x 2 columns]

# %%
all_videos = []
all_videos_details = []

for i in all_videoId:
    get_video_details(youtube_builder, i)
    all_videos.append(i)
    for video_id in all_videos:
        all_video_stats_df = get_video_stats(youtube_builder, video_id)
        all_videos_details.append(video_id)
        

# len(all_videos)

# %%
all_videos
# Out:
# [['d7y9z7pjCRM',
#   'yQThMUn_UmM',
#   'MEiq0oCUb_8',
#   'JuWF9G6SSi0',
#   'ErMwWXQxHp0',
#   '4SHlY9AoXzc',
#   'AxV0_1Y4zl0',
#   'DFgYGBtJLnI',
#   'UsD87v8F914',
#   'HeMIZC2rkMo',
#   'Jb88eui8SqQ',
#   'WfVF-Ec4naQ',
#   'lYPe4MsALk4',
#   'dKq_xfCz3Jk',
#   'cCCBDhdcSGw',
#   'pSdKnNj7ozk',
#   'CkoquiSnqbk',
#   'mrkAmmMakMg',
#   'xcjZvAFBH_Y',
#   'MjGMeMrH73I',
#   '4U2ZxO7b8iM',
#   'MUU0BjJjAvk',
#   'yCBEumeXY4A',
#   '6CsJZxfZsL0',
#   'U3DNz5asasA',
#   'ZQ4E0JJcxz0',
#   '7jaMJGtAV9M',
#   'q72dA533sCg',
#   'MiTG1ride7s',
#   'dQrBgda0sEY',
#   '1Cw-vODp-8Y',
#   'YJGFjL7E3vU',
#   'a6zvvlrd-jw',
#   'UpqaQR4ikig',
#   'yoigsHYc77s',
#   'wvhP1al3Ur4',
#   'pwHNannxolo',
#   'QpbGctuHoMY',
#   'Y5iif7YskU4',
#   'CMm7UZKtGNk',
#   '-EZ_3Tq9a8c',
#   'bTYV7aFC6KE',
#   'vXIAB_1FEC0',
#   'qWIkBMNKj1s',
#   'k_OOiuaZSKc',
#   'ldadR6XqiWE',
#   'vax8FCuQUsE',
#   'L-BN9Db5QhY',
#   '7IaYSxDp88s',
#   'BuaKzm7Kq9Q',
#   '-njHjebtIg4',
#   '-pTGc7cIBIA',
#   'zV7y4Oex1DQ',
#   '0Jc5Ryk2mCw',
#   'n4xw2fmSCrs',
#   'fBHq7U8hLp8',
#   'IDcyXtweHCw',
#   'SOq05_6w0ig',
#   'dp4nWm59esI',
#   '_VAlGmtfDN0',
#   'MZ8giCWDcyE',
#   'gkmzDwgvqQM',
#   'JnGXTk57rOU',
#   '7nM6EaR50Tc',
#   '9l3f1KrMQeo',
#   'CaaJyRvvaq8',
#   '9rvqDxBsJX4',
#   'rr2XfL_df3o',
#   'LcI6F_GPwfE',
#   '9hvjBi4PKWA',
#   'A1uYhkMRLWg',
#   'y72bAm4SvkE',
#   'roWxo6jWoYw',
#   'uhIdijSrnVc',
#   'BsosQkfa2L8',
#   '8FpPSMIB4uA',
#   'vBnpGIZK9R0',
#   'TnkdoEZhTbc',
#   'gny4B5YOV0s',
#   'g5ymJNLURRI',
#   'T-UhbAcZd3I',
#   'Fop2oskTug8',
#   'ZvPzY6MsmCs',
#   'C4sAUc_ZGMY',
#   'TLQkoZX9Mog',
#   'vXzuFprlyrw',
#   '1uu9VWBgcBU',
#   'Wk1oClYJE58',
#   'iLLi02P1FN4',
#   'SG3Zz_pfbOE',
#   'SvMhWghZ_EE',
#   'ek9bmIlDens',
#   '7hEPj13PUGc',
#   'dbAkuiS8PHU',
#   '6E9cdgMvQT0',
#   'TranVlEwQqw',
#   'DyKQ7qtTJag',
#   'n3XrvrBVg2k',
#   'DDpXdljhstg',
#   'O1sZcX-BBSA',
#   'CghqH21A2Ew',
#   'U3JprndeVYU',
#   'VaSstf9VJGQ',
#   'ILHEYblJ7uM',
#   'FITTkh-kf6g',
#   'wGKb3oUo8go',
#   'ZS-LwWzlKdc',
#   'J2npVg9ONFo',
#   'n2RNcPRtAiY',
#   'eY9dXcjkVx8',
#   'vSAa_ls9grQ',
#   'RTbrXiIzUt4',
#   'qNAo0UdYF6g',
#   '07mIwEa3xbQ',
#   't7jbT1YhyQU',
#   'ehv3zQAa9zM',
#   'vInUoPtg8m0',
#   'ccnlAVDXd7k',
#   'MhKiMPiZOdE',
#   'nLeScEdf550',
#   'tEmLMCPK8OE',
#   'k_vD2S49INE',
#   'ifI_fwg55k8',
#   'R5_v0OdFD0A',
#   'wUqZQTp_gpI',
#   'cW1KJf7JKgI',
#   'CAmZXCZ-e94',
#   'TP4VQTUbypM',
#   'RY63Nw0w33w',
#   '8eNNJESKjrE',
#   'fYAUINqHAY4',
#   'syiQmaGZFXM',
#   '1jmcloqc4yg',
#   '6pf2KJD5qf0',
#   'V7J9aMy_CFk',
#   'di1afyrEKoc',
#   'qVMdq9pDiuQ',
#   'Sye31IVjiss',
#   '9zkFfBVgVtI',
#   'dhAmMXCBIcg',
#   'DHvkyrey3JE',
#   'vLm68qbNjkU',
#   'MXtbeSbf_xM',
#   'tn2AgrwXpNQ',
#   '_fqxMZi7P7U',
#   '1l0aosZHSDA',
#   'lvV3jSLYK8A',
#   'wUBy2W1iKpo',
#   '9EOAEWC9hJ4',
#   'mx3krJHlUzc',
#   'pJlA2J92Fw4',
#   'Lt-fah4spJY',
#   'e6_t26Q9aVM',
#   'I49VNQ6lmKk',
#   'Gvvo6vUpJRc',
#   '4oco9pLw13E',
#   'zrbACeJ63II',
#   'UdfSrJvqY_E',
#   'Qfmeb2e_kb4',
#   '6uS5F1MSzaQ',
#   'kbeEkwlTeqQ',
#   'il9SZU_nsVc',
#   'l4bNwGCx1FA',
#   'noKpc8fo-R0',
#   'f4g2nPY-VZc',
#   'MepGo2xmVJw',
#   'b7RhbRujjUA',
#   'b6g6rDDt9x8',
#   'qrzCLgDplTw',
#   'Yhze-aRR6o0',
#   'imx_-6tHjhw',
#   'eWI_BtcDJu0',
#   'QtMzV73NAgk',
#   'X1b3C2081-Q',
#   'NBLO6RpofIU',
#   'j5zvFXmSGKY',
#   'nDy32xoXM4o',
#   'Sx6dAx7dnXg',
#   't0XN-dJftSU',
#   'wjXIw6OjBo8',
#   'stsJe7pJaKU',
#   'VHt0LqGZVSY',
#   'k1v7_zScivQ',
#   'j7QwJ-M_GAI',
#   'XDamqi_3Aro',
#   'azrdcp4yYas',
#   'cH66LWWluVE',
#   'kFz9afj8lu0',
#   'BAZX9p2oGOg',
#   'UFDoLyAE1Bc',
#   'Mm0NvlXdz4A',
#   'eAagtcAup0o',
#   'G4E2bbAgjXg',
#   '0fB2cQFp008',
#   'qDSaOwBHwbs',
#   'sy8K2VmWkDo',
#   'DJyxwIGdl8Y',
#   'Exk34o-MMIE',
#   '9Hk_rvjtxKc',
#   'R94ntpWVelw',
#   '5NNO5Kb-PZo',
#   'bInJjmH31Hk',
#   's6_azdBnAlU',
#   '6kAvCSMkYEI',
#   'mRvBCXMSrBE',
#   'dlHnleQU9tQ',
#   'Xzh8BdaaAvs',
#   'j52nXdQKFD0',
#   'IEwEDTmqCEs',
#   'Svf1lEUUCzU',
#   'nF4hg6g7SwE',
#   'W-VInHvlrZo',
#   '5nLWTVTwOhY',
#   'bATUW8G2ONE',
#   '8IB7JcKJEeI',
#   'Q2aaCDNjWEg',
#   'ZLyDvABxGF0',
#   '0we7kcmgDOw',
#   'QZgIArBFmmE',
#   'JztgJT547Vg',
#   'gfC8Y66tR6o',
#   'pLjtItOE88s',
#   'g9McJA3XEF4',
#   '0FC94Tgz2ho',
#   'o-_WXXVye3Y',
#   'Ns8ydpZ5-4o',
#   'bfbyCTyHFo4',
#   '_SoviSNZjso',
#   'ByayqNQU2fA',
#   'u41Zt6z5s7A',
#   'wUhf0sWhtKw',
#   'mBHY_Qaw5AI',
#   'Kl0E8p2IBmw',
#   '48bK3mmjgRE',
#   'nxf41fMX_Y4',
#   'WIVUbBIrbM4',
#   'IUyrlM1qkGU',
#   'aXfiyuUziY0',
#   'eNWG9KRAbCc',
#   'UK8HH3_q4yI',
#   'OHP1rLwR6r8',
#   'LTDuGU38-70',
#   '3qtIp8joCE0',
#   '2xiCVNwhrDU',
#   'CF0Q4iozRIA',
#   'x_R-qzjZrKQ',
#   'koPg_DZUfOc',
#   'ASwVyfebu3E',
#   '58xXl597B_4',
#   'O8FJSjy3bXA',
#   '9arevpoH-4g',
#   '-wOdL7HFNOs',
#   'PTpoj4f25dk',
#   '7wZbsAzNt1o',
#   'NZzQQ1090wc',
#   'mx8ZDMb5MBg',
#   'dPaHNTnN0eE',
#   'FV2tMP37ygs',
#   'hiiVniW6l7E',
#   'WPsvw_Db-y4',
#   'ZdC9soHxVC8',
#   'lCKcFFDgtNk',
#   '-DtSrdh5dHU',
#   '7xtX1KNSlrY',
#   'zHAB4qDsgKY',
#   'pgmHkfvGYnY',
#   'x1T-VTFiUwc',
#   'Jp8bBZHDULA',
#   'NbzpwG4n6Vs',
#   'sr2fBCzXo4g',
#   '-2pffpPl1lQ',
#   'gl62BSjp7Vo',
#   '4OnwUz-I2GI',
#   'TfYeJZeCCjk',
#   '07_IZIoN60Q',
#   'NvQmi_ciL1k',
#   'KxsFat1ImiY',
#   '2SkaD7Q53mA',
#   'fLRRStkhcuQ',
#   'DOPswcaSsu8',
#   'jdlGvS1y_Ls',
#   'nmnTAOU44SI',
#   '-YFKqKdD3_A',
#   'kOEXcMoh2II',
#   '6oHrNuXPVck',
#   'AjQ7CEeONb4',
#   'PRVr1heimY8',
#   'VJI88QIW7H4',
#   'BsAmXFcQMQ4',
#   'kMtN9KJHn5Y',
#   'ctWDAdQ81B8',
#   'mXgG8k5tTFM',
#   'OX1xG0a4TVo',
#   'oTZ84U-K_5k',
#   'wegxoNTw0_I',
#   'UCv7qwuLpHs',
#   'uDAv4qOU_04',
#   'zIjngBAxTr4',
#   'cG8PXdTlDag',
#   'DHiKz_lCYMU',
#   'q2CdBFA98SI',
#   'MrUhzYdcX6w',
#   'mfbSqTB74xM',
#   'zsEcLVHnxUM',
#   'sKJ4i7p-o-4',
#   'JR4KHfqw-oE',
#   '5TuyvWoaAZk',
#   'O6NiridP0Oo',
#   'ux4R5GeKMUU',
#   'omyZvH7aMtg',
#   'aeaBaTqmu8Q',
#   'OoY7zp8GkLI',
#   'XRiUNPf-_-4',
#   'DyX-QZZBgpw',
#   'QK8Se8CvyHc',
#   '-5BsYYtyENw',
#   '-Wwe5OW_jPE',
#   '5krV47BLyoQ',
#   'UVpJouUyLBM',
#   'XoH8no1MQWA',
#   'gNK_C78sBWY',
#   'pyldH6sefTQ',
#   '0T0rop9pE58',
#   '_CTUs_2hq6Y',
#   'oZVLZDBLROs',
#   'lj7kFBz-jw4',
#   'qrwBeXBxaWU',
#   'WpPw7lUXyI0',
#   'ROkXM3csNWY',
#   'rie69P0W668',
#   'FOp3L2OTG6g',
#   'JqyzwbpYYqc',
#   'YPln3JP_gKs',
#   'dZ_Ab1XxxKg',
#   'JdTBIHX-r0M',
#   'MOJ1_FtDGNs',
#   'M5NVwuyk2uM',
#   '3Yes-qyeJ_M',
#   'O2iorLuSjOg',
#   'Wf1lQdupvPE',
#   'QJxbqIo5pC0',
#   'xjFPX7EoINs',
#   'ySMGudnpdXQ',
#   'XnSqlX1kCQo',
#   'qZGpmWrVSaU',
#   'JEWzl4V2YBI',
#   'jFZ0MFYup-o',
#   'PVWLD3064Ng',
#   'vcaXm9dgcpI',
#   'iDKIw3OgNcg',
#   '6C_4Bz62b0E',
#   'yiyjcXWZ3Qo',
#   'Oy8zSYKkczI',
#   'vtqtyyGZvXM',
#   'x4yF3a3Zn4Y',
#   '0Z8J3axc0oY',
#   'QKyul7puruQ',
#   'qSlDIpD8lD4',
#   'VL9rd4NLXCo',
#   '3AfpFkrS7Lw',
#   '-8oT3dE0hik',
#   '0O4_EAGNg7k',
#   'KzdLNlCXQSo',
#   'OQri1NdscR4',
#   'TI4PXFUOPR8',
#   'Lg8B4aTZf7o',
#   'ay8Ya0DYDYE',
#   'faUEM-szlnY',
#   'f5_Gvt3mOx8',
#   'hYIqILk4lbs',
#   't9R7xx0joOU',
#   'iy1z3ZVASCg',
#   'YFtxYb-GN9k',
#   'cZIso9uqNls',
#   '4mxXdCUXSSs',
#   'BSQe-yQ5B84',
#   'AnH7cm9Y7CE',
#   'I65jo06QinI',
#   'iLA1XLO8p1A',
#   '9ZjlFZ3_b9E',
#   'yz0Cr_nfNM4',
#   'gfWjsKsEry0',
#   'D1pa3UX89GA',
#   'ZX5ajIAhKTk',
#   'Q-0V9v-ybKU',
#   'wIdpm7cKtFc',
#   'zZ8NuPIymlk',
#   'HOh6d_r63Bw',
#   'cpIEWsQpRMk',
#   'MdqKJxyIecE',
#   'P5dxd-ocaE8',
#   'LPY4u9Gx-xM',
#   '_5-bo8a4zU0',
#   'Mbc_yzB8oAY',
#   'e7sw5xA066Y',
#   'nuNYtj8keaE',
#   '6w6pEXZutoY',
#   'N1e_voQvHYk',
#   'xsiV_-o5488',
#   '9fyI-SEnNl8',
#   'bNLgikGu4Yw',
#   'Fd7BrGUSxqQ',
#   '_6-XjSvbJsE',
#   'uwxxQ9FZXow',
#   'vc1NdYXlaxA',
#   'E67Klqw2H-E',
#   'ogdZT9yUVe0',
#   'Lg9N8XAZ6u4',
#   'pIuSElb3Ous',
#   'LRh_iVXulXk',
#   'aYoGMsImJhw',
#   'ndphYju6PVM',
#   'sb77YWaEsi8',
#   'naIaW4pk_-o',
#   'YAF9BWpzwvI',
#   'zHOr6Ej_jd4',
#   'mgOQgciWLlg',
#   'GSWOs4_etoE',
#   'ZVoaNzRo0uo',
#   'iCvlOrK_mag',
#   'QPcagFrOnLE',
#   'T8stUe9Vo74',
#   'wIaowvCQG1M',
#   'ihEhAbVRC78',
#   'mr9kK0_7x08',
#   'MevKTPN4ozw',
#   '9AxYQOX5_FM',
#   '0sXvuUrJa0o',
#   'oOaQVvNK4EU',
#   '5_5zZnuB71w',
#   'JF-Fkbm0XjU',
#   'cVCRAKDt21E',
#   'nIs8xAr_nIo',
#   'fwijCB6cH-0',
#   'fJ_PNOXycwg',
#   'E5jxF9uMgKo',
#   'r6axJnv3jpQ',
#   'i7FtVfokRYU',
#   'GRSfvePdhPA',
#   'sWeeGAj61dA',
#   'ThkMi9fkdEc',
#   '0NX9RjQClvg',
#   '9gkxwIZPOZk',
#   'RROs-zCrSko',
#   'nt9J_PynaOM',
#   'HxVLdhm2B6Y',
#   '0PrUr3bQdwM',
#   'oD_3wMh5kLg',
#   'F0rYqvRk9r8',
#   'bSl9PfRX7WY',
#   'XU69_u7eXa0',
#   'USXoINPEhoA',
#   'SGiOZnUQlEU',
#   'hvFbmImsCc4',
#   'OJfOsoUYPts',
#   'TQG7m1BFeRc',
#   'Er-hGFBcosc',
#   'TKGA7MhxPWc',
#   'MtUxFCicxuM',
#   '4O9dNuiOWDg',
#   'UIwdCN4dV6w',
#   'rsJlT53jU_4',
#   'Xyt9rmsxwDU',
#   'Gzy_nCkn88U',
#   '6AlzUeJ9zn0',
#   'xIvaQ1Hv2Ug',
#   'pqQrL1K0Z5g',
#   'KB4_WIPE7vo',
#   'jn9mHzXJIV0',
#   'ZzefeQ0v5wg',
#   'J83sZrz9XTc',
#   'DC-QGkKrxdM',
#   'dRtqFjYYUY0',
#   'mpjREfvZiDs',
#   'jmvacbha8e8',
#   'C-DfipidnOE',
#   'FjsQkOt553Q',
#   'sVdIWxa4dpA',
#   '9O5PhuW927w',
#   '6joCzIxiUaE',
#   'A4EKZRlpcIM',
#   '9GqohosViw4',
#   '-IqpbDJFbZA',
#   '6UR_H5XJkeM',
#   'Js3WIRF595U',
#   'fL30bWrGrfE',
#   'aMQbRpxgFvs',
#   'ZWuPwcwl214',
#   'h-h5Mhlt6O0',
#   'xhybjeRciYg',
#   '49-rK7SAfQk',
#   'Wzvr_rtI82w',
#   'ELo58FBl3R8',
#   '4L-BPQVZYXM',
#   'ctx4YBEdOxo',
#   'Lxet1zLBTM8',
#   '9Ca8zWJOlFQ',
#   'Ja_GMU7-sjs',
#   'AL_GHdjQ7-Y',
#   'NwN_uIWpNOQ',
#   'LzC_kkbFTHQ',
#   'l0DoQYGZt8M',
#   'c4guh00dOaQ',
#   'KvNis_A6UaI',
#   'ilyTQSn2zRo',
#   'a-9IZz8Ry5I',
#   'PgeJ0XYuI2E',
#   'wd9-VP2LzM8',
#   '2iObySa91b0',
#   'ld5H2L4j6LE',
#   'xig77hiUHig',
#   'TxNSSlk__x4',
#   'H1KRDYZIOaw',
#   'wQD1JvJZXdI',
#   'Q07Cp6tswnQ',
#   'm__4JVtUTCk',
#   '_HTXMhKWqnA',
#   'iOnNXJs6FUU',
#   'Ca8F3_olFvA',
#   'ftqaMBDj2oY',
#   'UeoeaDvhGvQ',
#   'XOoCGWk3y0s',
#   '-_WbmSxZnB8',
#   'hQZp6lp-3as',
#   'sdw_jquVZe0',
#   'r7ygnDKpFRE',
#   'BkpAro4zIwU',
#   'tQzqFbwWPSk',
#   'ywk2-xx0LP0',
#   'MgzwBW_LPdE',
#   'QnmpkMz69ZE',
#   'ZNAxkJL5OKU',
#   'ygMHYJEtk2c',
#   'l5nv86zjPro',
#   'uxxEjI27dwg',
#   'Wp-SqWal3VQ',
#   'W-YQr2HhORc',
#   'OkPter7MC1I',
#   '2BQ1rCqG19Y',
#   '2w5B1Ne-fy4',
#   '3Dl8wLo1W6E',
#   'z3X49SYvbo0',
#   'lENFECCD4ms',
#   'RvXmktAurSQ',
#   'dbWGjcHz9xA',
#   'oSnoYEzZnUg',
#   'A9ZvwOsLplU',
#   'ZPY7dIz0GBI',
#   'VEVWRGC0OJA',
#   'JBjCH8nRBYE',
#   'BfOLimMAhrs',
#   '6lCQqpvdgLQ',
#   'CnTuumKNvrI',
#   'DFKFnkP_sLQ',
#   'qfy6Bbro8GI',
#   'DtmGMcMeEJE',
#   'nNlTNE1y9DM',
#   '0n1x-wxESaM',
#   'n_SDw2LQ9N8',
#   '4DlNrCZFNGo',
#   'xfG15i_uQvc',
#   'Lm0QkWqMqHQ',
#   'Fz-6MdlPY1M',
#   'mJY-HhPcFhQ',
#   'zOMGY22XQs8',
#   'VDsjYTMyh94',
#   'Nq2Kum-eG8g',
#   '9VbD649W8EY',
#   'jbXEWi-OK4o',
#   'g-WWzf3wUik',
#   'HRgtHE9_3KU',
#   'X0ggW9mA22k',
#   '60OkiR1ujdg',
#   'f0NdOE5GTgo',
#   'xcSOGYqQ_kY',
#   'Vr3ya_uPmxg',
#   '5JdHSmaRiP4',
#   'J49hiExRUmQ',
#   'srj-NLj4Kt0',
#   'xXjQ6UoHs5U',
#   '9g2oMlstdwY',
#   'qtXZlpJP-Ik',
#   'M2VvFXCR3II',
#   'XIzimkcuEuk',
#   '67plwXQk6Ek',
#   'eFLTXiT5Rso',
#   'NKY93vCiPIo',
#   'QM5z0dW60KE',
#   'H3ZDtArXS6I',
#   'KftNp6hdO5g',
#   'DhCJuJoE6wM',
#   'Y6tzhAg0fQQ',
#   'C9Plog9I1JY',
#   '1cpUwbr5YyE',
#   'tXp-_3jvKsI',
#   'Snzshdl3hHI',
#   'KXr6ZNwWPXE',
#   '0f_BTRPUr6k',
#   'iuOslAj9-5A',
#   'LR708uA4zQ8',
#   '7q48xYdb8is',
#   '77aeW3bsCzc',
#   'WmHtebBGzjg',
#   'gWoqwCGQIM0',
#   'm7plA1ALkQw',
#   'JFiu5rfnhzo',
#   'iHwC92t2yQ4',
#   'mOwYlhUbsko',
#   'b-Bux7YrzxY',
#   'J8esUVOF-G4',
#   'xQLb_uwWzj8',
#   'XGFQOZ_owtc',
#   '-7q4lqhvlVQ',
#   'lV70CxFlx7w',
#   '-ICgMYIzhxg',
#   'XMAwwpYQd7E',
#   'J5HtSy5bATk',
#   'uVRcbo9_OdA',
#   '7TAPdmSuYBQ',
#   'BUsL-IxPquA',
#   'W82ErGmjUik',
#   '4l8eeqgCJnQ',
#   'ptni6tRrU54',
#   '0Ae0YwmgYTY',
#   'C2p5aREEWvk',
#   'ObDkWUm10OQ',
#   'yXYZQFTs8h0',
#   'OvyzimtwCdU',
#   'iaUW8Cn8fc0',
#   '2b1VPqCrk2c',
#   'AeuIE0gTYgg',
#   'DAxj9CjczXw',
#   'yD2iHEW09wk',
#   'ycIpOZY03OM',
#   'Hew1t8XZbPs',
#   'juzeLmUMjv0',
#   '96PJdbJysxQ',
#   'GiNSOLpC1-Y',
#   'mGojonPKBkY',
#   'ya7VlofjdwY',
#   'XVL0ybe18yI',
#   '9kiECQodMqE',
#   'amP7GVlUv2I',
#   'wsN6AHN2FbM',
#   'FBWvXZP_frg',
#   '5IJWckL5L84',
#   'K_34vZ9haCk',
#   'Tx_lyy4-SeY',
#   'ZvPxjhTOEgM',
#   'C-8Ux5ZQLLI',
#   '1sgeM6DsV40',
#   '8bMbcNUM68U',
#   'V2nPsyyme5I',
#   'RCgPD2sfbAQ',
#   'O6aSIa1sk6g',
#   '7SKRn_VNwNA',
#   'xdmuzyg50Vg',
#   'WmhKCq0vfjE',
#   'dU1YfSZDClE',
#   'itInMEcvjYc',
#   '2JlDVUcedbo',
#   'xCRjWur8-7c',
#   'gGrPigM0NeE',
#   'LeLi_Whav3I',
#   'QkcJL_FARp8',
#   '0hUxIO09hPA',
#   'C5UiAaeHdgg',
#   'vZLZtH5hnKo',
#   'X3DmlFkC2cI',
#   'ShcnNkr_PEY',
#   'UBuVR8_Mybw',
#   'h0BSqrfXBjM',
#   'dP5Au3tH448',
#   'AqkBD2FK7KE',
#   '-tuHrt42WnI',
#   '9TWB32376QA',
#   'fgK-bxZIG-o',
#   '9E006QLHt0Y',
#   'kEMmKu4tYWI',
#   'K-jYDRd_53w',
#   'XAoQPp9XLt8',
#   'ldS_yHnZMDs',
#   '0NTOZbjg6SE',
#   'YuHD9h5gTS4',
#   'zulLRv0GFhM',
#   'Xc5fFvp8le4',
#   'qv-RVkpQTWs',
#   '1K3iMWgAQzI',
#   'm1fUil7QLNI',
#   '2IIUHleexIk',
#   'cqybfPNbWBA',
#   'E357cGzOGLM',
#   'MQ9GDfE3BZg',
#   'gM_gTtll7FE',
#   '7jrmnPFlqG0',
#   'V-nBAcr_huw',
#   'HALtebWHpNA',
#   'gN-MeB-S8Kw',
#   'nL9Guwuv8HY',
#   'JWv3oRaZO9Y',
#   's8Un0XB_8xk',
#   'Nmkab1LUqlg',
#   'LObJOc5u7sY',
#   'q6kIwfEGLO4',
#   'Aq6RRmDExeI',
#   '9HDKRP4nzc0',
#   'cx20nTPZjes',
#   'cqLMQCG5pCs',
#   '91av8wCH7CI',
#   'xpc07Lbgrow',
#   'orPHNS-0CZI',
#   'VDiOv9148gc',
#   'XtLpZLM4jg0',
#   '5Nnu5Vdhwfs',
#   '9sTVbeq21dI',
#   'GkqI_2Fp9ok',
#   '6RskGkGYtgg',
#   'g0n2zT9xBdM',
#   'TA8JprZlDYA',
#   'VgmyVHYV1mE',
#   'UrzhzCA1NUw',
#   'XZvqQ4xK1R8',
#   'N3NPXB3eiPY',
#   'VTUDzrIgZlI',
#   '4CJvasYJP6o',
#   'dPL1-8ypnEs',
#   'Qfd8nck5cP4',
#   'Ws9KAQS02Yo',
#   'lpwa5iYOjU8',
#   'WjUebpBA2AE',
#   'Mhvv2-iCKao',
#   '4Q6kdHSWNZM',
#   '5x6DELO6Sz4',
#   'sBO5RKq8PXc',
#   'JDJDeuJbiKc',
#   'i4Zt3JZejbg',
#   '8syPkiANwYk',
#   'ZrZISyPucMg',
#   'GttoIyB_lEQ',
#   '2ircZoqveuA',
#   'QXF3tUfvuLU',
#   'TtLHiiXyERA',
#   'KrxrzzTUPD8',
#   'UUBDiUy2824',
#   '3yoAj-PRsZ0',
#   'KG9E5LaI8bk',
#   'UJ9Lbao6j-c',
#   'nnODX_VEp2c',
#   'aJinPXrOZYk',
#   '7hXjxLrDf5I',
#   '9nTJlmsa_Bo',
#   't8eKwFESN8s',
#   '_z9q096Lhj0',
#   'dIfLmM0YkXM',
#   'arlvHJnfFKI',
#   '26C_O6hDMjQ',
#   'CjYPLWcgAOE',
#   'Zh2wtbNrlyw',
#   'f6pPIG3EvAs',
#   'vE-P7zzCCsU',
#   'aEDJkbSJKP0',
#   'RoAPTdvgAJg',
#   'lMGggUDolRI',
#   'DqVPbEcWtA0',
#   'W-QoakKxTjg',
#   '7h-R73VTXXQ',
#   'YyrUBJQmUGs',
#   'pEDQ1z1-PvU',
#   'hoQKLOrAU4E',
#   'Wwp9eaVVW_8',
#   'opVgMDtBecA',
#   'iTLp2F4dm4I',
#   '61TAqY03xwk',
#   'wspZXjeWWq4',
#   'SlTvgY9PeCQ',
#   '3kYDVzwcwcg',
#   's3QcOSyD38M',
#   'XSf33i8njNU',
#   'BK3YvlOFRTg',
#   'X8DOUSGGw10',
#   'nxM-rac7vb4',
#   'uALVIcQXH4Q',
#   '8tU-0Uxz6jw',
#   'ZsxQxS0AdBY',
#   'EC00YntB7LQ',
#   'PNp2IjVv3HI',
#   '9HtGhNUtW-E',
#   'sFGEBTdK2Z0',
#   '2z9uOm-Ydrk',
#   'RUC_F0OQdDg',
#   '5BRVHKG_hpU',
#   'hgj1x0ecJMo',
#   'b7ANcWQEUI8',
#   '5R0_FJ4r73s',
#   'W8BfirN9z94',
#   'TmikWdsrz_U',
#   'y9ue7TNpxS0',
#   'U13DF7R-iuw',
#   'yBWNZTYPbzA',
#   '6trOg2IK2Zg',
#   '7QH1qFd24bY',
#   'BOOa1wZhkzY',
#   'yAyR_YHEZ_c',
#   'lXPvnhNcMs0',
#   'Btr8uOU0BkI',
#   'Ij9njxJUyUQ',
#   'd6605kiXmm8',
#   'AVpfhoi_uOM',
#   '2XvDb37qIdg',
#   'FrgGHAab9D8',
#   'NH_7FqSuxkU',
#   'EcMBuRX-EdU',
#   'c4zAPmQZmYA',
#   'R7siKvpvuCM',
#   'jzezFz6CMqg',
#   'Ew5ZzloH4Mg',
#   'QahWCPNALDA',
#   'z8gOX35dAfc',
#   'pwsPZi_JRrA',
#   'pmnLca3FneU',
#   'd7n34bkF-Ew',
#   'zSlt_2X8sPw',
#   'pZiKLNnanWs',
#   'VQW48jzIcjk',
#   'D0mCG1BeZCo',
#   'paENIboxKGI',
#   'lvNrGxpS2jY',
#   'fbwEaql90Ac',
#   'RwnSX-3ncSA',
#   'y5DyEYuvF3o',
#   'fKDuVDZqQ1c',
#   'r5TvTH3GOdc',
#   '8QF3qJ0U5K0',
#   'qauddPrHLqU',
#   'KBXTLLFgDeo',
#   'EtKa0ORwaU0',
#   'dYzlWWa8dCU',
#   'MVyA-T2lNNk',
#   '_ibTYAxssQw',
#   'szd7M-Qi1MI',
#   'tYGg1fIfuOY',
#   'BldsuTqsI1g',
#   'YGziBcgP93Y',
#   'M8rSmmLNYUc',
#   'L6RW1KaNuL0',
#   'dYmHFsH6E7g',
#   '8L7d6_ZzyoU',
#   'Rrm4isCQDkQ',
#   '8f7mFHYjBG0',
#   'BZjIsZwgKfo',
#   'E0_JrUNevdc',
#   'lVPAfntOfmc',
#   'tTfaaqXYXxQ',
#   'KFD0Nm2dOHw',
#   'kpqBNn_BfKE',
#   '3GrIWdORHvc',
#   'pMFLeoDx6J4',
#   '3AbWtn1ixVk',
#   'Z-W66HINFLg',
#   'tTxhneVcmEo',
#   'Hr8E-_yU2YA',
#   '1dg2UIzIt4s',
#   'RBCaAq_pKjY',
#   '1JEXDBWehvI',
#   'f7TD3Z03l2I',
#   'skXwTxo0Bo0',
#   'P4Hbn6xcD9M',
#   'hUgOgMCKXqs',
#   'z6dkNLn9br0',
#   'OMb-jXlkNwY',
#   'uBEaG6n0XDs',
#   'F0zhwl8454Y',
#   '9NSBB-kFDGQ',
#   'PYJAiY6zuMo',
#   'WBeFfWUdseI',
#   'uQyRDqnr0FM',
#   'IovZRv8toDM',
#   '6Smu8YbwZ9Q',
#   'fsOxwsFF50c',
#   'elXk87IKgCo',
#   '8yKXTr7KB40',
#   'Fi1JUykQBKw',
#   'lEjwyYOFwZg',
#   'h3wKBfAIdzE',
#   'CJTlB_S7ct0',
#   'wEpMtf6nJco',
#   '3ZX8graseUQ',
#   'wwXA27TWD3k',
#   'TK4u6wm-HIk',
#   'nei16gkVxpg',
#   'YmuOwOb35qs',
#   'TTWJq2MpCx4',
#   'fNt-QXLp6YI',
#   'CntfUc_Sd1c',
#   'tC1LxFS5uA4',
#   'saoiKoNvnn8',
#   'epLszn-rnpA',
#   'zb5Wp_i8oQo',
#   '4i3oKEg6o9g',
#   'QrM25jqhXdA',
#   'WxWLVwBqAOc',
#   'H9HH0vqb4q8',
#   'yR0ZGltMUTM',
#   'BygqMgC3W10',
#   'aYtAdCDOCfU',
#   'Cdbn_pmxFic',
#   'onldzSzdqlM',
#   'c74d5kqSEvo',
#   'ZWKl-FeUApA',
#   'jpiPzgBJU9M',
#   'KF75-HPdUfY',
#   'wXmzpFoHkfA',
#   '_bozaSWsDuE',
#   'rIRpK7KAfM0',
#   'swXI_sl5m3I',
#   'jZoh_QKnGbc',
#   'T88kUY9Q3es',
#   '1gUQhN5joSQ',
#   'LDBWrSENTps',
#   'Py6g_FheJWI',
#   'ul3lgaU_lbY',
#   'o9PT9HDXZWs',
#   'zUtedhbQDP4',
#   'PGXhG82HRX0',
#   'GlhXpHULwys',
#   'qp5il7yhM4Y',
#   '6d0lEMp8Vtk',
#   '83Y31z3ZI2A',
#   'CP5LB1eQff0',
#   'xU2fB0pQJkA',
#   'LkOC0gbNF20',
#   'MQ97Kymd6X0',
#   'uj0S2rgmu-M',
#   'XkqiFOvF8v0',
#   '6A-PpwfM1wo',
#   'Wm4jH01Sluc',
#   'N4fpYnzqHEM',
#   'Rd89JLYsoOI',
#   'K9CNsBCmrNg',
#   'mVLyd9_czWE',
#   '9qf3OmxwmhM',
#   'NSWOvw5N4nU',
#   'HVL6Kwk8IOA',
#   'SEXiPc3q1tg',
#   'tRyEYlvb66I',
#   'YginQUkrJ50',
#   'PAs6yQUCkno',
#   '8gca3uud87c',
#   '6PEmKUBtWlk',
#   'iwaW6HR9dw4',
#   'NyoM_i1jJZc',
#   'gfPNNdY1Fjs',
#   'FFuePFTf9LQ',
#   'uO0Q7SMZvfg',
#   'q1zZ8cGF1OI',
#   'IysmRC4aAFc',
#   'xVlzDdxaaaE',
#   'zFOnOLXrMBQ',
#   'bJOGQ_SJ8Dc',
#   'RvfjuYUe6-w',
#   'yRaIjn6q9Jo',
#   'nCVygTgQKUs',
#   'G43tYXIlUV4',
#   'RQy0NeVnxLo',
#   'Tqm8Izfn_oU',
#   'WeHC3qjt1Ws',
#   '7Tw9Yk-6jkQ',
#   'PPEpTasDz2s',
#   'y2d2tlnNYOg',
#   '2No-AEasdz8',
#   'GFdzwQw4CxQ',
#   'VdsMwGWvhO4',
#   'eFcpRIwPqRc',
#   'JpsTUT4F3BA',
#   '-gqjCVTXBeM',
#   'C-b9hmerTac',
#   'hKvoHRAYyMc',
#   'kRB1-APKUqs',
#   '1E6PDgIwFg4',
#   'aSZ2GogKawQ',
#   'Teyx-jx2Ano',
#   'MS3VXAUZcJE',
#   'APQqX8Xd5TA',
#   'IT73da-C4sw',
#   '3L27XnwKWkY',
#   '_02K6efDLI0',
#   '_hhEz4Uo79k',
#   'b_xRPA0CjJg',
#   'YddnWW_JYiY',
#   'bK959V_9XgQ',
#   'ddI-ZZwFclc',
#   'eG0As9lWP7I',
#   'nzikcaYKOkY',
#   'K7uLph0s6f0',
#   'kw-RzN4xYyE',
#   'poSFV9_abcw',
#   '4nKRZA4HVQg',
#   '4JEZ2rrf2N4',
#   'xAT0EmZc-LE',
#   'CultO7cPnJA',
#   ...],
#  ['nhOnLlshf60',
#   'QEo7b36mOcM',
#   'BnXRS18K7gc',
#   'fu_M9EmP_gk',
#   'J_0teOgTAhQ',
#   'YOSQIUGGdYE',
#   'GK6WCUnhUg0',
#   'IqHO9k0fcZo',
#   'gqYaqBVT5vM',
#   'fKoDe6kw_ZE',
#   'krnZUfixffY',
#   'OsQymqWRu6Y',
#   'uWzwovY9u-E',
#   'SNjlnEIGtfw',
#   '_3-rscgRsYM',
#   'duj4CvXimQU',
#   'Aao-RX5DZcA',
#   '1WIFY7_TZUE',
#   'lWqlDixckSI',
#   '6fPj6mj-M_k',
#   'LkYB931iUjc',
#   'NSVUw3KF5PE',
#   'WMGrMWybnrw',
#   'jFGhvYLbBRE',
#   'sJ2x2JVCh1Q',
#   'pmCQtrKBALU',
#   '8_v2SA5uLbc',
#   'pDQGqipmuFA',
#   'zxcvwuaXC_w',
#   'JexvBG9J6qA',
#   'S5iXvDAwNVI',
#   'rHA87rBVkk8',
#   '3kLr60XFr90',
#   'Gw6taLNMIXI',
#   'VjiLBhmiMMw',
#   'VHUF8A2vpos',
#   't3MAu9WxPAE',
#   'PdBTkgtnTsw',
#   'oDwY5N0Bk_w',
#   '3mTV1TOblbA',
#   '1uDfnHoPq3w',
#   'P6mrmEtmBhE',
#   'A0qJahE3y7I',
#   'gVqy_RWtae8',
#   'p2PpqZeMkSs',
#   'SQAfcJ_BHyE',
#   'uUR8V4oBCvA',
#   'IhqCC70ZfDM',
#   '1onnyw9ZMkY',
#   'BH0NbsjeIVQ',
#   'HStRHwwb8Vo',
#   '_ofku--J9ps',
#   '82nGC_uNdqQ',
#   'VAj7jiRtG-A',
#   '7pzlQ69QslQ',
#   '09tZRhiWi-0',
#   'bE75-erVKP0',
#   'ECMcAkbsOEM',
#   'YnRIEXP85k8',
#   'x-Fs-wAmbRY',
#   'PMRZWAVyerM',
#   'jZGhwdeHFSs',
#   'dqX9g7AaqhM',
#   'jmgBwMHpP1w',
#   '5-q55JsyVrc',
#   'TAavlpk2Uuk',
#   '0i_XWYKfIdY',
#   'Xhc3Rq_HZYE',
#   'JKx9P1F8pww',
#   '-zTNuxUl5lM',
#   'UcCl5xG9w7Y',
#   'JLXvC_zykVo',
#   'otGEEanj7gA',
#   '-S5_MQH9jDA',
#   'TMFEEOjQ0tA',
#   'NyhsWXCrToc',
#   'HEZKVkl89zk',
#   'iQyIRvy0rko',
#   'yduMkPn1Vfc',
#   'e5AQNDOP1nA',
#   '3WuxHYFFZ-E',
#   '_e7JTaPMf7Q',
#   'OY2jMXKVhIw',
#   'o54aKk5LZdM',
#   '0WH3itALMrw',
#   'DAYwEhoGJDA',
#   'E59xZyDFiJ8',
#   'tZezzz6tY3o',
#   '651JOj-E1qo',
#   'FKDdeJSyRTw',
#   'GCNbuehl1gg',
#   '2CcBqXzxhFg',
#   'BruI_wB2PSE',
#   '8Uv-ffvBXOg',
#   'MnQXRfCo7aU',
#   'fGtO7oE1Bhk',
#   'WKN9nvXTGHE',
#   '1ZdO8jT5TaY',
#   'teupd0VBGCc',
#   'l3daDnnz-2o',
#   'XeXt1T3p8UI',
#   'DU3OcUvivyo',
#   'lh-ujKV8qcA',
#   'HuB4fd73G_8',
#   'hFVXBUZlQyY',
#   'ztTY788z9NE',
#   'biQbRjeaoHw',
#   '5-lNLNfKr3s',
#   'KuoHW5EiJdQ',
#   'eA95G-sc-TU',
#   '3iLT6iDu8Ds',
#   'iWh1gEKqL7g',
#   'TQdRipT1L28',
#   'LcLi8W0Ysmc',
#   'qhQzCayvfZ8',
#   '-XHPGGE8-Uo',
#   'QhGXjJSg2jA',
#   '_o-D-bgXAKM',
#   'CD8Z_YQkV1o',
#   'ZfgNiVjKAzc',
#   'HLhG8U6ziqs',
#   'YHZp6b8qJew',
#   'aDWgr7YEdTA',
#   '16ayIgVCb5c',
#   'rfYydagxcJI',
#   'QY7lHH521SE',
#   'U7HxYOaFr88',
#   'r7svkjbsnK8',
#   'l5DLz7Ms11g',
#   'VCf6PX0PKNE',
#   'XQ6vX6nmboU',
#   'l2qgTyTVUgI',
#   'Gby4KOzzEEg',
#   'zHwi3Yq6tZM',
#   '7yjea4JxBX8',
#   'qXPiKA5zgT0',
#   'tIqlu4sm5OQ',
#   'Mya3ZvVRTRg',
#   'ybt03airuTk',
#   '0FnX1ufiMzM',
#   'ig5t1nU-mxk',
#   'MfIYLXMhUl8',
#   'Squ0ZCwQga0',
#   'Cp9UoJxW89U',
#   'cFyka8Vp62Y',
#   'V3fSJPlAjAo',
#   'bp6m0L--zSE',
#   'DJDBe5s59b0',
#   'EUJ8333SN3s',
#   'jgLOfZaV3Ac',
#   'pjdcUqJNk5c',
#   '2vaVH0SJa3s',
#   'HybxSfUtvgY',
#   'Luq2IdQvwWc',
#   '-1WdsHDEdUk',
#   'jsumNIdzAZs',
#   'haMV_nkkYsA',
#   'gU3iuGqx5Wg',
#   'S0S6kni_Ff0',
#   '9mRxyH0RWuQ',
#   'IyYgnx80qkY',
#   'EMFCVvy0rkE',
#   'ktoZIF3AN9E',
#   'cwTlJYVNorI',
#   'uNSyXJte4TU',
#   'oAy9EuBRCpg',
#   't7sOFoS-IRk',
#   'rHUnrPy7N6A',
#   '0QLu9gMhQNQ',
#   'AKFRDiI3oEE',
#   'weU1pYsMnRk',
#   'kkvzHjuZAb8',
#   'gzaiCR-o5Hk',
#   'j3T_imAj6uI',
#   'R2yNky1CM3c',
#   'F1uT_oT5aow',
#   'q2KjrPT8u8c',
#   'YyBYHNjQgrQ',
#   'PG6jxXgrOh0',
#   'xSsd-6xjHfw',
#   '5_C8oa8zkAE',
#   'tagUtlYFhJQ',
#   'xSP8u4iiLEg',
#   'DAxSM8yPs1k',
#   '9h6AAqd4Lno',
#   'ynyKcAvvQ1w',
#   'MJcRy2Q6nYU',
#   'vidX3RZQXBI',
#   'XyRUWM_LOPQ',
#   'xDmRpcQQPUo',
#   '-hSOuK7qBgM',
#   'C8sS1rRMXII',
#   'Maz7qkLzwYw',
#   'HS2F8NWV4cQ',
#   'qdqJfFkQKEI',
#   'yN1FJCkwWf0',
#   'ElRn6AX9IBs',
#   'lojuls2PmYs',
#   'JwX4gQzudYM',
#   'NaSGsrHiK88',
#   'qTO7959ySss',
#   'h-ronBX8pxA',
#   'dcszY8OP-zw',
#   'NLyZHFTNGfw',
#   'UlN8xu5ooYo',
#   'qlbAQArT7YQ',
#   '2SfSUjxNHtE',
#   'YVpQ4xV_VB0',
#   'gLO7643fT1E',
#   'tFsLpLOEUIk',
#   'v5PEXWv--G8',
#   'YF3P2-I8bVc',
#   'C5SSsle77oY',
#   'UaK5xguzD_A',
#   'rHwbgza_QJE',
#   'qyuyKwMujCY',
#   '8zdJ9qUZxUo',
#   'khXwVtzhraI',
#   '_v5IzvVTw7A',
#   'ZJ6hc9Scd3s',
#   'cHxOBS97fDU',
#   'bp65vZEzIuo',
#   'OG5-MVpkQjg',
#   'MPnzBxCmBKk',
#   '10tXmE1IXw0',
#   'A7hgf-RfHyc',
#   'WTr5o0Axkpc',
#   'wQjxHfLfdy0',
#   '65EY5fbwJCY',
#   'TQ8SpKaXkWg',
#   '6oTCwTLV-Kw',
#   'R9MamtGWl9E',
#   'FEkYd1qF5Ko',
#   'ByCDKBBhdZg',
#   'i0k3JPFtw60',
#   'xniDjNQtqyg',
#   'PDdNGsqi1Ho',
#   '3F0WDu0_tn0',
#   'DhgPCAvRW7Y',
#   'tKxHJixw87s',
#   'HEZqanWT27w',
#   'NYl97rTsevQ',
#   '68uhLlX6BJI',
#   'Nt8UWWqa7uM',
#   'KbuCQqV_ULI',
#   '25eFzFXcdyA',
#   'vcYlYRRHsCI',
#   'uDqmLrpMz7A',
#   'RzGCFDYKQM0',
#   '5GhCaAkWuSo',
#   '8MkyTIU_ZLk',
#   'GzXiDhd6loM',
#   'TL1LLfmtD0w',
#   'vzB-rxPF6cw',
#   'YlkFUB_XLVs',
#   'PpGk15i6eTc',
#   'iJvr0VPsn-s',
#   '5kFEg2fRxA4',
#   'cdt5mIzIFco',
#   'BiFgSAcn_ls',
#   'l0HmxGNQ_ao',
#   'ENJwA9MVHz8',
#   '92vWhjZmNbg',
#   'ouiOZsIatGQ',
#   'uDEIyjm-Uls',
#   'QBHws9hPJYs',
#   '1CEDr7VvNaw',
#   'TktssLcTt7Q',
#   'phDTqsgU5kA',
#   'YyMiZCXRMQY',
#   'rNKMrEcrNZQ',
#   'K7pEmHo1CkQ',
#   'sMib1nMCdfc',
#   'N4zVExS5mgg',
#   'NLfAQQlSOwc',
#   'wNLbP45aTO8',
#   'b6-qoXEYY10',
#   '-zZYVCeoOeA',
#   '8wSYgT9shSY',
#   'n95wxMxz_us',
#   'y5LTnJI2Nm0',
#   '9Cor70qmThU',
#   'jPFiDIYUUxo',
#   'HdUAEYqK5tE',
#   'cYsNQF20b5I',
#   'desL7v-gBUk',
#   'z8AdxtkkQDo',
#   'Ov3Nq1WkUMI',
#   'LPJHd9asM7w',
#   'otHviixLykI',
#   'G0inmw5q6kk',
#   'pdUKug8XahU',
#   'fJATz_Mu2Wg',
#   'Hz2AUON5jmY',
#   'PfgMdGWVyiQ',
#   'TNR3xPNxzgM',
#   'U-SPrjbeElU',
#   'yjrmjarfzmI',
#   'FqoxQaFG_9c',
#   'W15yKKbHE80',
#   'Mmlv3ksJ2BA',
#   'HfnQfO9p5EE',
#   'h22xb2x0sTc',
#   'pAEVLUeYaf8',
#   'pXkE0BlTBmI',
#   '0FQ6WGJkLPs',
#   'bTUytmEYx6s',
#   '0yfF0Mri_t8',
#   'iqv7btFcIFo',
#   'DFjKYBa6ZqU',
#   'we2I6pd3KlI',
#   'WxRblujlYOg',
#   '6bLG0GcCYik',
#   'S5-12O3kiho',
#   'xu6-yuDVp1Y',
#   '6022e03wp2E',
#   'mykA0jrZWF0',
#   's1C2cNdAzI0',
#   'lzAhPhA3JGE',
#   '-GPgoiq-rdE',
#   'Y7zS-ZICkWk',
#   '1bEoAI5DMrA',
#   'OiKQpnWndOg',
#   'inPgVEy6ojg',
#   '2_azRm5CQ7g',
#   'rKcWT1LIH3M',
#   'Kp1vy6fBhPM',
#   'oY9e59FS7Tw',
#   'ohbpuBO6-9Q',
#   'IsgNhhlIUrU',
#   'NhmwRxwwSTA',
#   '3PtbK_0j1sw',
#   'PIoJeY0rx-w',
#   '3mQh7mFgeBc',
#   'G7LVgdfCNOw',
#   'UdQxMux_cu0',
#   'CQtpiBqVQyY',
#   '0xT_2jfVaII',
#   'Aj6vXhN-g6k',
#   'tcUQG0MC_OQ',
#   'idjy3AUmozY',
#   '96ZKECaj180',
#   'tSRfYteappo',
#   '8DULIfYDyBo',
#   '0tx3nmA2pSM',
#   'pBfkVKvQrcU',
#   'nGplsMkStVM',
#   'HQgdLvSlQdc',
#   'mtDQTKqidXY',
#   'JE_Ja_6nlbg',
#   'BUisXF5_TCU',
#   'S7900rTHdCo',
#   'lTTOaXffYZc',
#   'BXMBvKPRsEo',
#   'wUwVfaJfnBE',
#   '33THbvTODdM',
#   'qg5HeTGSv3I',
#   'tJW0ZYxQqgs',
#   'A2bSYFJ73oE',
#   'ADEh9F0Lidc',
#   '2oWw8pwXlZA',
#   'TAt2EMsszuk',
#   'ZdwtnZUUOWo',
#   'HubbDiz0nsc',
#   'sc69B9b-TVw',
#   'BJRccu6aXHM',
#   '71-Ji7OtriY',
#   'UKEVljWNaA8',
#   'STqRlcuZbHs',
#   'DFEi8gKMqIM',
#   '7gwBxKHBoEI',
#   'GJLlxj_dtq8',
#   '-CVqAVX5aAc',
#   'KrKws3D3ZDw',
#   'UTguywiC9aw',
#   'xeUlGnNUut8',
#   'Dx8J125s4cg',
#   '18PA3WFFuAo',
#   'VTSwlRFyFlw',
#   'emHyQNfQKaw',
#   'mdRpgWYWCZg',
#   'QrK7pGmwlNY',
#   'gLQTKwY-vJI',
#   'vpAiZBrzQdM',
#   'y_Vx3kt3NUw',
#   'UQaHNS7oCWY',
#   'NYRsJnViBgs',
#   '0pO7DWIfR6Y',
#   'g6QZcvqyE-Y',
#   'MCDEY2MFnF8',
#   'b5wGGp88nBs',
#   'aXjIz-vH3oY',
#   '9lzvoBCOlJM',
#   'H-gQLLUU5fM',
#   'WY7-Q6JKijs',
#   '5qXUy5EQb1c',
#   'WMg8SJJEC2I',
#   's8aCPlUhXTg',
#   'gE92XtxCnyg',
#   '7O40VobH7NU',
#   'WbGaqJehEHw',
#   'MzaQrNUrXoY',
#   'TvXBl063ixk',
#   'dgFday9MrmA',
#   'zQT8rMlqfqI',
#   'iTZlYpaOZfw',
#   'yEV9MGrxbEU',
#   'E_2ptII-7DY',
#   '-DbCq7FRSDc',
#   'EavSblb031o',
#   'hpJ6Tzoz-ZY',
#   'ajTUqSXzZis',
#   'ujws3_SLMPk',
#   'KWBjfoioS20',
#   'pJqbhRRZx8w',
#   'cyJ7aWLWSSM',
#   'RtmHCT8WQRI',
#   '9AIJpbokB80',
#   'vLAucnrFDOQ',
#   'ZPNgL1Ss7fU',
#   'HQgZh-eGESw',
#   'p-W5W_KIsUw',
#   'NM3u-0eKVFE',
#   'nPFYvVuqZLI',
#   'GWRwuilpbGw',
#   'C-gwT7sI8SU',
#   'S6fjNq0PGYo',
#   'KRSSXwLVgao',
#   'v2-ytP-HllE',
#   'U0BjO3Z-CXM',
#   'GGt4yJL09IU',
#   'HbNYuOTaYFs',
#   'egaGs_mFQns',
#   '22OcG-OAdQw',
#   'Syar32OLFNE',
#   'HPfjKPzitIQ',
#   'M-NRyniYjeE',
#   'gilkylyKIpg',
#   'ulrFWWk9UM8',
#   'ZIDYBeJ-UKE',
#   'CBZHavTlT6w',
#   '85_fSnZ6NUM',
#   'WdYBSJyxtdo',
#   'RARKNr6ru-c',
#   'GDtkEbxY_6k',
#   '9L0ENfK9wvM',
#   '2RQLoqTnQJo',
#   'axSIWl_pMrI',
#   'FopoTlnNRRs',
#   '-VLKdC8awMk',
#   'fsGEkCw_B70',
#   'fJEFIQSdsqw',
#   'EDecUtVfKmU',
#   'rPUccVeV4I0',
#   'IKAKcgYIHWY',
#   'ZBePB1Um7FM',
#   'aiYZZmEdXlQ',
#   'bi2WfEI5V7Y',
#   'tAi2tkbsaxA',
#   '1Rv6h55ZDiE',
#   'mJ22d23rCXA',
#   'f2rfwR-IV-c',
#   'Dq3PhCK7cn4',
#   'gwQeXeJuuyQ',
#   'efkQrXv4ckc',
#   'ZADtgM56wvE',
#   'gTDResMIK_w',
#   'JxQ-9pXoIJM',
#   'ydzC7jb5C4s',
#   'qPR27T-1vag',
#   'XhEOpqwZeNQ',
#   'MDapV6EE2_w',
#   'mTS7juj9N1E',
#   'KCRRYzan7BU',
#   'vv1W0C920oE',
#   'EKUn7MpfQMg',
#   'sSgqyd2Mcdc',
#   'KNbWi-KzAik',
#   'XW5Z4Vsda7U',
#   'SKFlz4to3ks',
#   '_3JZRxVPuew',
#   'ZXrc1wNS0L8',
#   'L9Jqnyt__Ps',
#   'zHaPSrpyYlE',
#   'tNCwvihWO78',
#   'kUDjt4gjMO4',
#   'R_8BsUZIHgc',
#   'al_5-BDDFPs',
#   'ImO-vBmL4gk',
#   'd6VJSZsKN0Y',
#   '-DaDjFm7_qw',
#   'EIc6v4C0_-w',
#   'im0FA2X6fp0',
#   'rXQJTW6uBq4',
#   '1pqioE3jqwg',
#   'aHKqhRjRkbE',
#   'No5RbW1A2Ss',
#   'vsi3xRXryUA',
#   'YcPm16U55sE',
#   'pX56Sj4XzGM',
#   'F0ZOqg8JjsE',
#   'Laz6NL55FD4',
#   'uH0UQl5JC2c',
#   'c4ikwbO_rho',
#   'oQgaEL8gn3Q',
#   '6ysFDaHpMfg',
#   'xkzh7mfY1ik',
#   'WBAzdNdCVxw',
#   'e_aSht_ssls',
#   'fURkRSbO20k',
#   'ddDvm7C1RMo',
#   'wQBtzNCuCAA',
#   '6tpe_6ILN5k',
#   'qxwMlYMMSnI',
#   'k_GM1JA608Y',
#   'CAZ0aH-hiUU',
#   'DRVQqndA7rA',
#   'a59U6kRJHLg',
#   'eg3u-rRjYF8',
#   '4vY0NqKNmB4',
#   'wtSlhqHolso',
#   'BSMOp8nBKes',
#   'rvhH0DW85DA',
#   'Gb7a9Alm_ZM',
#   'f-dH7_WUwI8',
#   'O82mvIMBzPg',
#   'QBNP5I2y668',
#   'DDZW6ZUESzg',
#   'Tf3095vIE1I',
#   '0siMCwXf6-E',
#   'xlBmdFORhZ8',
#   'jTMRestOZ3I',
#   'wAiH6rdr78Q',
#   'wEb0mWN5-gE',
#   'ZQFn1Z-x9DQ',
#   'EnhtpjbNHWY',
#   'aZ_0mh9Z4AQ',
#   'FSmXA01l-_8',
#   'mVV2fF352qk',
#   'iKkIrd-OMvM',
#   'vvAB3U5umug',
#   'NLsDn59fxdQ',
#   'Ws7S5lXw7zk',
#   'CCQ8NJUz2Ss',
#   '6EzMVumwxqI',
#   'ZH0hBJTpEkI',
#   'l8ZGbxskrVE',
#   'ibVhqq9Asqw',
#   'zhhxK83hWzU',
#   'G_VUD7r0gVA',
#   'gDPs9o_L1GI',
#   'niExdgR14Gk',
#   'ac9ogKirkGQ',
#   'Dtjllca-AaQ',
#   'ZZDUJeUhX9c',
#   'fiYNaTeRYC8',
#   '_i83H3FDGw8',
#   'e2ZanubcQjE',
#   'rRmwJVXo16Y',
#   'y62POiaRbtU',
#   'diRhFErwN_g',
#   'TTTGiUi9Jfw',
#   'dRm8g7Y0plM',
#   'Ymnv_h4763A',
#   'GXRLOEeSC9Q',
#   'A6ijaVcLWE0',
#   'icQMelb7mKY',
#   '2Ohf1owHuQ8',
#   'VftseA5k7Zk',
#   'UEDLieBoTsI',
#   'lvkZRMPM8aQ',
#   'IDJd_9CMkEg',
#   'jW0a3UikQqk',
#   'WSnT2UHrpEk',
#   'rH7SoJUpnNA',
#   'TEFIF8dX3yU',
#   '7LB7OA_2dgI',
#   'rGLDGoG0DJU',
#   'OCWRdrpQ83w',
#   'Ke162NPmBbE',
#   '1eJYl5y6q6M',
#   '_ze5p_hG6wY',
#   'Dvzle0olkj0',
#   'w2BdiAbz6iA',
#   'KHrJ9IA60MI',
#   'e6DuYZeVx2M',
#   'BOFZGCwoRmo',
#   '_XLTaK5oz3c',
#   'TN-Rub-lmc4',
#   'chgG_9rmDgg',
#   'f-iD0YrkFfI',
#   'RsxhcTs0zJ8',
#   '7MmN30IixrQ',
#   'jRWJeKbhMK8',
#   'P33QHwPqdWM',
#   'E5hZb7Eo-2g',
#   '6TcoAnk_Q-c',
#   'oEIGX1MTh-M',
#   's0mXMTjZy5M',
#   'lvsPxoldsic',
#   'hJZM6i32MZ0',
#   '2rCKUcaS198',
#   'dolFOVPUp-4',
#   'dYC9OpV_PvI',
#   'FkmisXljv8w',
#   'XODqm66ooMQ',
#   '_kYgiPN-bJU',
#   'I4SgcraOAOU',
#   '5Xby_KZmHsw',
#   'XDtTvAkKT4g',
#   'wn8SpOoY_aw',
#   '2K3mrnkSHxw',
#   '31ZIhan9eu8',
#   'TXUOB9EuUIc',
#   'uWUztGO5puE',
#   'ZRmRamdNFHg',
#   'pcbfAuehGsc',
#   'hCl7IR16U7A',
#   'xyGnAMxhXGA',
#   '8eWGcKR3ho4',
#   'r_8yFIYxP4s',
#   '9-603kcKyMI',
#   'qA-8_OpUdEM',
#   'BYdntBKpJnw',
#   'i_HzXNRI1DE',
#   'e7IH8MjUuUo',
#   '57ISNozMfYk',
#   '4m4GqChBz4Q',
#   'keziN-DEK6M',
#   'vyNrgSue3E4',
#   'VWbYR1z467Y',
#   'XzQPkDk07FM',
#   'K0wpV0xRKXg',
#   'jWTbZLPoYKc',
#   '0BwVW2-G0EU',
#   '9BUdJhjWTH0',
#   '9F1k53y4Rf8',
#   'Gqubax7O1bY',
#   '5Ay1RLg9_Pk',
#   'OxSkQLHcjcE',
#   '3C18M-bsmxY',
#   'BpxZED9IMi8',
#   'oMN7ycsXfCo',
#   'aUGbl-Rced0',
#   '5H6d4MA-6X8',
#   'bMOtP68xR6g',
#   'mH_swkTcsFw',
#   'XFQ4La8te1M',
#   'ULd_sxplvf4',
#   'KW2Xk8fksfM',
#   '9kxeOShI5Dc',
#   '0QylvO0d48s',
#   'Z2vlynTXjqA',
#   'OzLxTjwqRjw',
#   '9yFrMgEerAs',
#   'mDPjqf33m8k',
#   'aiA0wWKXIPo',
#   '8acCb5O1Uyc',
#   'jlLxtG__HTw',
#   'W3VDcUP60sE',
#   'zlIMsqn1etk',
#   'HvAOiZEJI-k',
#   'BnUyVt-IgBI',
#   'zwOcWuAbuxs',
#   'UULEkS-oOaE',
#   '0JBz0W6KW04',
#   'KXjbppME-hg',
#   'G5vZfGxNSzA',
#   'QtUCtOu0-Bs',
#   'Yk1CGk0TZAw',
#   'qWl7vdTFJqM',
#   'aRQHvynk7IA',
#   '7PCj7_buAik',
#   '5P5QwVlB2kg',
#   'XnFh3s74Dxg',
#   'qL4vZjhwJsk',
#   '0NOcojVOgeI',
#   'e_r_qNy7bno']]

# %%
all_video_list = []
for i in all_videos:
    all_video_list.append(i)

# %%
all_video_list
# Out:
# [['d7y9z7pjCRM',
#   'yQThMUn_UmM',
#   'MEiq0oCUb_8',
#   'JuWF9G6SSi0',
#   'ErMwWXQxHp0',
#   '4SHlY9AoXzc',
#   'AxV0_1Y4zl0',
#   'DFgYGBtJLnI',
#   'UsD87v8F914',
#   'HeMIZC2rkMo',
#   'Jb88eui8SqQ',
#   'WfVF-Ec4naQ',
#   'lYPe4MsALk4',
#   'dKq_xfCz3Jk',
#   'cCCBDhdcSGw',
#   'pSdKnNj7ozk',
#   'CkoquiSnqbk',
#   'mrkAmmMakMg',
#   'xcjZvAFBH_Y',
#   'MjGMeMrH73I',
#   '4U2ZxO7b8iM',
#   'MUU0BjJjAvk',
#   'yCBEumeXY4A',
#   '6CsJZxfZsL0',
#   'U3DNz5asasA',
#   'ZQ4E0JJcxz0',
#   '7jaMJGtAV9M',
#   'q72dA533sCg',
#   'MiTG1ride7s',
#   'dQrBgda0sEY',
#   '1Cw-vODp-8Y',
#   'YJGFjL7E3vU',
#   'a6zvvlrd-jw',
#   'UpqaQR4ikig',
#   'yoigsHYc77s',
#   'wvhP1al3Ur4',
#   'pwHNannxolo',
#   'QpbGctuHoMY',
#   'Y5iif7YskU4',
#   'CMm7UZKtGNk',
#   '-EZ_3Tq9a8c',
#   'bTYV7aFC6KE',
#   'vXIAB_1FEC0',
#   'qWIkBMNKj1s',
#   'k_OOiuaZSKc',
#   'ldadR6XqiWE',
#   'vax8FCuQUsE',
#   'L-BN9Db5QhY',
#   '7IaYSxDp88s',
#   'BuaKzm7Kq9Q',
#   '-njHjebtIg4',
#   '-pTGc7cIBIA',
#   'zV7y4Oex1DQ',
#   '0Jc5Ryk2mCw',
#   'n4xw2fmSCrs',
#   'fBHq7U8hLp8',
#   'IDcyXtweHCw',
#   'SOq05_6w0ig',
#   'dp4nWm59esI',
#   '_VAlGmtfDN0',
#   'MZ8giCWDcyE',
#   'gkmzDwgvqQM',
#   'JnGXTk57rOU',
#   '7nM6EaR50Tc',
#   '9l3f1KrMQeo',
#   'CaaJyRvvaq8',
#   '9rvqDxBsJX4',
#   'rr2XfL_df3o',
#   'LcI6F_GPwfE',
#   '9hvjBi4PKWA',
#   'A1uYhkMRLWg',
#   'y72bAm4SvkE',
#   'roWxo6jWoYw',
#   'uhIdijSrnVc',
#   'BsosQkfa2L8',
#   '8FpPSMIB4uA',
#   'vBnpGIZK9R0',
#   'TnkdoEZhTbc',
#   'gny4B5YOV0s',
#   'g5ymJNLURRI',
#   'T-UhbAcZd3I',
#   'Fop2oskTug8',
#   'ZvPzY6MsmCs',
#   'C4sAUc_ZGMY',
#   'TLQkoZX9Mog',
#   'vXzuFprlyrw',
#   '1uu9VWBgcBU',
#   'Wk1oClYJE58',
#   'iLLi02P1FN4',
#   'SG3Zz_pfbOE',
#   'SvMhWghZ_EE',
#   'ek9bmIlDens',
#   '7hEPj13PUGc',
#   'dbAkuiS8PHU',
#   '6E9cdgMvQT0',
#   'TranVlEwQqw',
#   'DyKQ7qtTJag',
#   'n3XrvrBVg2k',
#   'DDpXdljhstg',
#   'O1sZcX-BBSA',
#   'CghqH21A2Ew',
#   'U3JprndeVYU',
#   'VaSstf9VJGQ',
#   'ILHEYblJ7uM',
#   'FITTkh-kf6g',
#   'wGKb3oUo8go',
#   'ZS-LwWzlKdc',
#   'J2npVg9ONFo',
#   'n2RNcPRtAiY',
#   'eY9dXcjkVx8',
#   'vSAa_ls9grQ',
#   'RTbrXiIzUt4',
#   'qNAo0UdYF6g',
#   '07mIwEa3xbQ',
#   't7jbT1YhyQU',
#   'ehv3zQAa9zM',
#   'vInUoPtg8m0',
#   'ccnlAVDXd7k',
#   'MhKiMPiZOdE',
#   'nLeScEdf550',
#   'tEmLMCPK8OE',
#   'k_vD2S49INE',
#   'ifI_fwg55k8',
#   'R5_v0OdFD0A',
#   'wUqZQTp_gpI',
#   'cW1KJf7JKgI',
#   'CAmZXCZ-e94',
#   'TP4VQTUbypM',
#   'RY63Nw0w33w',
#   '8eNNJESKjrE',
#   'fYAUINqHAY4',
#   'syiQmaGZFXM',
#   '1jmcloqc4yg',
#   '6pf2KJD5qf0',
#   'V7J9aMy_CFk',
#   'di1afyrEKoc',
#   'qVMdq9pDiuQ',
#   'Sye31IVjiss',
#   '9zkFfBVgVtI',
#   'dhAmMXCBIcg',
#   'DHvkyrey3JE',
#   'vLm68qbNjkU',
#   'MXtbeSbf_xM',
#   'tn2AgrwXpNQ',
#   '_fqxMZi7P7U',
#   '1l0aosZHSDA',
#   'lvV3jSLYK8A',
#   'wUBy2W1iKpo',
#   '9EOAEWC9hJ4',
#   'mx3krJHlUzc',
#   'pJlA2J92Fw4',
#   'Lt-fah4spJY',
#   'e6_t26Q9aVM',
#   'I49VNQ6lmKk',
#   'Gvvo6vUpJRc',
#   '4oco9pLw13E',
#   'zrbACeJ63II',
#   'UdfSrJvqY_E',
#   'Qfmeb2e_kb4',
#   '6uS5F1MSzaQ',
#   'kbeEkwlTeqQ',
#   'il9SZU_nsVc',
#   'l4bNwGCx1FA',
#   'noKpc8fo-R0',
#   'f4g2nPY-VZc',
#   'MepGo2xmVJw',
#   'b7RhbRujjUA',
#   'b6g6rDDt9x8',
#   'qrzCLgDplTw',
#   'Yhze-aRR6o0',
#   'imx_-6tHjhw',
#   'eWI_BtcDJu0',
#   'QtMzV73NAgk',
#   'X1b3C2081-Q',
#   'NBLO6RpofIU',
#   'j5zvFXmSGKY',
#   'nDy32xoXM4o',
#   'Sx6dAx7dnXg',
#   't0XN-dJftSU',
#   'wjXIw6OjBo8',
#   'stsJe7pJaKU',
#   'VHt0LqGZVSY',
#   'k1v7_zScivQ',
#   'j7QwJ-M_GAI',
#   'XDamqi_3Aro',
#   'azrdcp4yYas',
#   'cH66LWWluVE',
#   'kFz9afj8lu0',
#   'BAZX9p2oGOg',
#   'UFDoLyAE1Bc',
#   'Mm0NvlXdz4A',
#   'eAagtcAup0o',
#   'G4E2bbAgjXg',
#   '0fB2cQFp008',
#   'qDSaOwBHwbs',
#   'sy8K2VmWkDo',
#   'DJyxwIGdl8Y',
#   'Exk34o-MMIE',
#   '9Hk_rvjtxKc',
#   'R94ntpWVelw',
#   '5NNO5Kb-PZo',
#   'bInJjmH31Hk',
#   's6_azdBnAlU',
#   '6kAvCSMkYEI',
#   'mRvBCXMSrBE',
#   'dlHnleQU9tQ',
#   'Xzh8BdaaAvs',
#   'j52nXdQKFD0',
#   'IEwEDTmqCEs',
#   'Svf1lEUUCzU',
#   'nF4hg6g7SwE',
#   'W-VInHvlrZo',
#   '5nLWTVTwOhY',
#   'bATUW8G2ONE',
#   '8IB7JcKJEeI',
#   'Q2aaCDNjWEg',
#   'ZLyDvABxGF0',
#   '0we7kcmgDOw',
#   'QZgIArBFmmE',
#   'JztgJT547Vg',
#   'gfC8Y66tR6o',
#   'pLjtItOE88s',
#   'g9McJA3XEF4',
#   '0FC94Tgz2ho',
#   'o-_WXXVye3Y',
#   'Ns8ydpZ5-4o',
#   'bfbyCTyHFo4',
#   '_SoviSNZjso',
#   'ByayqNQU2fA',
#   'u41Zt6z5s7A',
#   'wUhf0sWhtKw',
#   'mBHY_Qaw5AI',
#   'Kl0E8p2IBmw',
#   '48bK3mmjgRE',
#   'nxf41fMX_Y4',
#   'WIVUbBIrbM4',
#   'IUyrlM1qkGU',
#   'aXfiyuUziY0',
#   'eNWG9KRAbCc',
#   'UK8HH3_q4yI',
#   'OHP1rLwR6r8',
#   'LTDuGU38-70',
#   '3qtIp8joCE0',
#   '2xiCVNwhrDU',
#   'CF0Q4iozRIA',
#   'x_R-qzjZrKQ',
#   'koPg_DZUfOc',
#   'ASwVyfebu3E',
#   '58xXl597B_4',
#   'O8FJSjy3bXA',
#   '9arevpoH-4g',
#   '-wOdL7HFNOs',
#   'PTpoj4f25dk',
#   '7wZbsAzNt1o',
#   'NZzQQ1090wc',
#   'mx8ZDMb5MBg',
#   'dPaHNTnN0eE',
#   'FV2tMP37ygs',
#   'hiiVniW6l7E',
#   'WPsvw_Db-y4',
#   'ZdC9soHxVC8',
#   'lCKcFFDgtNk',
#   '-DtSrdh5dHU',
#   '7xtX1KNSlrY',
#   'zHAB4qDsgKY',
#   'pgmHkfvGYnY',
#   'x1T-VTFiUwc',
#   'Jp8bBZHDULA',
#   'NbzpwG4n6Vs',
#   'sr2fBCzXo4g',
#   '-2pffpPl1lQ',
#   'gl62BSjp7Vo',
#   '4OnwUz-I2GI',
#   'TfYeJZeCCjk',
#   '07_IZIoN60Q',
#   'NvQmi_ciL1k',
#   'KxsFat1ImiY',
#   '2SkaD7Q53mA',
#   'fLRRStkhcuQ',
#   'DOPswcaSsu8',
#   'jdlGvS1y_Ls',
#   'nmnTAOU44SI',
#   '-YFKqKdD3_A',
#   'kOEXcMoh2II',
#   '6oHrNuXPVck',
#   'AjQ7CEeONb4',
#   'PRVr1heimY8',
#   'VJI88QIW7H4',
#   'BsAmXFcQMQ4',
#   'kMtN9KJHn5Y',
#   'ctWDAdQ81B8',
#   'mXgG8k5tTFM',
#   'OX1xG0a4TVo',
#   'oTZ84U-K_5k',
#   'wegxoNTw0_I',
#   'UCv7qwuLpHs',
#   'uDAv4qOU_04',
#   'zIjngBAxTr4',
#   'cG8PXdTlDag',
#   'DHiKz_lCYMU',
#   'q2CdBFA98SI',
#   'MrUhzYdcX6w',
#   'mfbSqTB74xM',
#   'zsEcLVHnxUM',
#   'sKJ4i7p-o-4',
#   'JR4KHfqw-oE',
#   '5TuyvWoaAZk',
#   'O6NiridP0Oo',
#   'ux4R5GeKMUU',
#   'omyZvH7aMtg',
#   'aeaBaTqmu8Q',
#   'OoY7zp8GkLI',
#   'XRiUNPf-_-4',
#   'DyX-QZZBgpw',
#   'QK8Se8CvyHc',
#   '-5BsYYtyENw',
#   '-Wwe5OW_jPE',
#   '5krV47BLyoQ',
#   'UVpJouUyLBM',
#   'XoH8no1MQWA',
#   'gNK_C78sBWY',
#   'pyldH6sefTQ',
#   '0T0rop9pE58',
#   '_CTUs_2hq6Y',
#   'oZVLZDBLROs',
#   'lj7kFBz-jw4',
#   'qrwBeXBxaWU',
#   'WpPw7lUXyI0',
#   'ROkXM3csNWY',
#   'rie69P0W668',
#   'FOp3L2OTG6g',
#   'JqyzwbpYYqc',
#   'YPln3JP_gKs',
#   'dZ_Ab1XxxKg',
#   'JdTBIHX-r0M',
#   'MOJ1_FtDGNs',
#   'M5NVwuyk2uM',
#   '3Yes-qyeJ_M',
#   'O2iorLuSjOg',
#   'Wf1lQdupvPE',
#   'QJxbqIo5pC0',
#   'xjFPX7EoINs',
#   'ySMGudnpdXQ',
#   'XnSqlX1kCQo',
#   'qZGpmWrVSaU',
#   'JEWzl4V2YBI',
#   'jFZ0MFYup-o',
#   'PVWLD3064Ng',
#   'vcaXm9dgcpI',
#   'iDKIw3OgNcg',
#   '6C_4Bz62b0E',
#   'yiyjcXWZ3Qo',
#   'Oy8zSYKkczI',
#   'vtqtyyGZvXM',
#   'x4yF3a3Zn4Y',
#   '0Z8J3axc0oY',
#   'QKyul7puruQ',
#   'qSlDIpD8lD4',
#   'VL9rd4NLXCo',
#   '3AfpFkrS7Lw',
#   '-8oT3dE0hik',
#   '0O4_EAGNg7k',
#   'KzdLNlCXQSo',
#   'OQri1NdscR4',
#   'TI4PXFUOPR8',
#   'Lg8B4aTZf7o',
#   'ay8Ya0DYDYE',
#   'faUEM-szlnY',
#   'f5_Gvt3mOx8',
#   'hYIqILk4lbs',
#   't9R7xx0joOU',
#   'iy1z3ZVASCg',
#   'YFtxYb-GN9k',
#   'cZIso9uqNls',
#   '4mxXdCUXSSs',
#   'BSQe-yQ5B84',
#   'AnH7cm9Y7CE',
#   'I65jo06QinI',
#   'iLA1XLO8p1A',
#   '9ZjlFZ3_b9E',
#   'yz0Cr_nfNM4',
#   'gfWjsKsEry0',
#   'D1pa3UX89GA',
#   'ZX5ajIAhKTk',
#   'Q-0V9v-ybKU',
#   'wIdpm7cKtFc',
#   'zZ8NuPIymlk',
#   'HOh6d_r63Bw',
#   'cpIEWsQpRMk',
#   'MdqKJxyIecE',
#   'P5dxd-ocaE8',
#   'LPY4u9Gx-xM',
#   '_5-bo8a4zU0',
#   'Mbc_yzB8oAY',
#   'e7sw5xA066Y',
#   'nuNYtj8keaE',
#   '6w6pEXZutoY',
#   'N1e_voQvHYk',
#   'xsiV_-o5488',
#   '9fyI-SEnNl8',
#   'bNLgikGu4Yw',
#   'Fd7BrGUSxqQ',
#   '_6-XjSvbJsE',
#   'uwxxQ9FZXow',
#   'vc1NdYXlaxA',
#   'E67Klqw2H-E',
#   'ogdZT9yUVe0',
#   'Lg9N8XAZ6u4',
#   'pIuSElb3Ous',
#   'LRh_iVXulXk',
#   'aYoGMsImJhw',
#   'ndphYju6PVM',
#   'sb77YWaEsi8',
#   'naIaW4pk_-o',
#   'YAF9BWpzwvI',
#   'zHOr6Ej_jd4',
#   'mgOQgciWLlg',
#   'GSWOs4_etoE',
#   'ZVoaNzRo0uo',
#   'iCvlOrK_mag',
#   'QPcagFrOnLE',
#   'T8stUe9Vo74',
#   'wIaowvCQG1M',
#   'ihEhAbVRC78',
#   'mr9kK0_7x08',
#   'MevKTPN4ozw',
#   '9AxYQOX5_FM',
#   '0sXvuUrJa0o',
#   'oOaQVvNK4EU',
#   '5_5zZnuB71w',
#   'JF-Fkbm0XjU',
#   'cVCRAKDt21E',
#   'nIs8xAr_nIo',
#   'fwijCB6cH-0',
#   'fJ_PNOXycwg',
#   'E5jxF9uMgKo',
#   'r6axJnv3jpQ',
#   'i7FtVfokRYU',
#   'GRSfvePdhPA',
#   'sWeeGAj61dA',
#   'ThkMi9fkdEc',
#   '0NX9RjQClvg',
#   '9gkxwIZPOZk',
#   'RROs-zCrSko',
#   'nt9J_PynaOM',
#   'HxVLdhm2B6Y',
#   '0PrUr3bQdwM',
#   'oD_3wMh5kLg',
#   'F0rYqvRk9r8',
#   'bSl9PfRX7WY',
#   'XU69_u7eXa0',
#   'USXoINPEhoA',
#   'SGiOZnUQlEU',
#   'hvFbmImsCc4',
#   'OJfOsoUYPts',
#   'TQG7m1BFeRc',
#   'Er-hGFBcosc',
#   'TKGA7MhxPWc',
#   'MtUxFCicxuM',
#   '4O9dNuiOWDg',
#   'UIwdCN4dV6w',
#   'rsJlT53jU_4',
#   'Xyt9rmsxwDU',
#   'Gzy_nCkn88U',
#   '6AlzUeJ9zn0',
#   'xIvaQ1Hv2Ug',
#   'pqQrL1K0Z5g',
#   'KB4_WIPE7vo',
#   'jn9mHzXJIV0',
#   'ZzefeQ0v5wg',
#   'J83sZrz9XTc',
#   'DC-QGkKrxdM',
#   'dRtqFjYYUY0',
#   'mpjREfvZiDs',
#   'jmvacbha8e8',
#   'C-DfipidnOE',
#   'FjsQkOt553Q',
#   'sVdIWxa4dpA',
#   '9O5PhuW927w',
#   '6joCzIxiUaE',
#   'A4EKZRlpcIM',
#   '9GqohosViw4',
#   '-IqpbDJFbZA',
#   '6UR_H5XJkeM',
#   'Js3WIRF595U',
#   'fL30bWrGrfE',
#   'aMQbRpxgFvs',
#   'ZWuPwcwl214',
#   'h-h5Mhlt6O0',
#   'xhybjeRciYg',
#   '49-rK7SAfQk',
#   'Wzvr_rtI82w',
#   'ELo58FBl3R8',
#   '4L-BPQVZYXM',
#   'ctx4YBEdOxo',
#   'Lxet1zLBTM8',
#   '9Ca8zWJOlFQ',
#   'Ja_GMU7-sjs',
#   'AL_GHdjQ7-Y',
#   'NwN_uIWpNOQ',
#   'LzC_kkbFTHQ',
#   'l0DoQYGZt8M',
#   'c4guh00dOaQ',
#   'KvNis_A6UaI',
#   'ilyTQSn2zRo',
#   'a-9IZz8Ry5I',
#   'PgeJ0XYuI2E',
#   'wd9-VP2LzM8',
#   '2iObySa91b0',
#   'ld5H2L4j6LE',
#   'xig77hiUHig',
#   'TxNSSlk__x4',
#   'H1KRDYZIOaw',
#   'wQD1JvJZXdI',
#   'Q07Cp6tswnQ',
#   'm__4JVtUTCk',
#   '_HTXMhKWqnA',
#   'iOnNXJs6FUU',
#   'Ca8F3_olFvA',
#   'ftqaMBDj2oY',
#   'UeoeaDvhGvQ',
#   'XOoCGWk3y0s',
#   '-_WbmSxZnB8',
#   'hQZp6lp-3as',
#   'sdw_jquVZe0',
#   'r7ygnDKpFRE',
#   'BkpAro4zIwU',
#   'tQzqFbwWPSk',
#   'ywk2-xx0LP0',
#   'MgzwBW_LPdE',
#   'QnmpkMz69ZE',
#   'ZNAxkJL5OKU',
#   'ygMHYJEtk2c',
#   'l5nv86zjPro',
#   'uxxEjI27dwg',
#   'Wp-SqWal3VQ',
#   'W-YQr2HhORc',
#   'OkPter7MC1I',
#   '2BQ1rCqG19Y',
#   '2w5B1Ne-fy4',
#   '3Dl8wLo1W6E',
#   'z3X49SYvbo0',
#   'lENFECCD4ms',
#   'RvXmktAurSQ',
#   'dbWGjcHz9xA',
#   'oSnoYEzZnUg',
#   'A9ZvwOsLplU',
#   'ZPY7dIz0GBI',
#   'VEVWRGC0OJA',
#   'JBjCH8nRBYE',
#   'BfOLimMAhrs',
#   '6lCQqpvdgLQ',
#   'CnTuumKNvrI',
#   'DFKFnkP_sLQ',
#   'qfy6Bbro8GI',
#   'DtmGMcMeEJE',
#   'nNlTNE1y9DM',
#   '0n1x-wxESaM',
#   'n_SDw2LQ9N8',
#   '4DlNrCZFNGo',
#   'xfG15i_uQvc',
#   'Lm0QkWqMqHQ',
#   'Fz-6MdlPY1M',
#   'mJY-HhPcFhQ',
#   'zOMGY22XQs8',
#   'VDsjYTMyh94',
#   'Nq2Kum-eG8g',
#   '9VbD649W8EY',
#   'jbXEWi-OK4o',
#   'g-WWzf3wUik',
#   'HRgtHE9_3KU',
#   'X0ggW9mA22k',
#   '60OkiR1ujdg',
#   'f0NdOE5GTgo',
#   'xcSOGYqQ_kY',
#   'Vr3ya_uPmxg',
#   '5JdHSmaRiP4',
#   'J49hiExRUmQ',
#   'srj-NLj4Kt0',
#   'xXjQ6UoHs5U',
#   '9g2oMlstdwY',
#   'qtXZlpJP-Ik',
#   'M2VvFXCR3II',
#   'XIzimkcuEuk',
#   '67plwXQk6Ek',
#   'eFLTXiT5Rso',
#   'NKY93vCiPIo',
#   'QM5z0dW60KE',
#   'H3ZDtArXS6I',
#   'KftNp6hdO5g',
#   'DhCJuJoE6wM',
#   'Y6tzhAg0fQQ',
#   'C9Plog9I1JY',
#   '1cpUwbr5YyE',
#   'tXp-_3jvKsI',
#   'Snzshdl3hHI',
#   'KXr6ZNwWPXE',
#   '0f_BTRPUr6k',
#   'iuOslAj9-5A',
#   'LR708uA4zQ8',
#   '7q48xYdb8is',
#   '77aeW3bsCzc',
#   'WmHtebBGzjg',
#   'gWoqwCGQIM0',
#   'm7plA1ALkQw',
#   'JFiu5rfnhzo',
#   'iHwC92t2yQ4',
#   'mOwYlhUbsko',
#   'b-Bux7YrzxY',
#   'J8esUVOF-G4',
#   'xQLb_uwWzj8',
#   'XGFQOZ_owtc',
#   '-7q4lqhvlVQ',
#   'lV70CxFlx7w',
#   '-ICgMYIzhxg',
#   'XMAwwpYQd7E',
#   'J5HtSy5bATk',
#   'uVRcbo9_OdA',
#   '7TAPdmSuYBQ',
#   'BUsL-IxPquA',
#   'W82ErGmjUik',
#   '4l8eeqgCJnQ',
#   'ptni6tRrU54',
#   '0Ae0YwmgYTY',
#   'C2p5aREEWvk',
#   'ObDkWUm10OQ',
#   'yXYZQFTs8h0',
#   'OvyzimtwCdU',
#   'iaUW8Cn8fc0',
#   '2b1VPqCrk2c',
#   'AeuIE0gTYgg',
#   'DAxj9CjczXw',
#   'yD2iHEW09wk',
#   'ycIpOZY03OM',
#   'Hew1t8XZbPs',
#   'juzeLmUMjv0',
#   '96PJdbJysxQ',
#   'GiNSOLpC1-Y',
#   'mGojonPKBkY',
#   'ya7VlofjdwY',
#   'XVL0ybe18yI',
#   '9kiECQodMqE',
#   'amP7GVlUv2I',
#   'wsN6AHN2FbM',
#   'FBWvXZP_frg',
#   '5IJWckL5L84',
#   'K_34vZ9haCk',
#   'Tx_lyy4-SeY',
#   'ZvPxjhTOEgM',
#   'C-8Ux5ZQLLI',
#   '1sgeM6DsV40',
#   '8bMbcNUM68U',
#   'V2nPsyyme5I',
#   'RCgPD2sfbAQ',
#   'O6aSIa1sk6g',
#   '7SKRn_VNwNA',
#   'xdmuzyg50Vg',
#   'WmhKCq0vfjE',
#   'dU1YfSZDClE',
#   'itInMEcvjYc',
#   '2JlDVUcedbo',
#   'xCRjWur8-7c',
#   'gGrPigM0NeE',
#   'LeLi_Whav3I',
#   'QkcJL_FARp8',
#   '0hUxIO09hPA',
#   'C5UiAaeHdgg',
#   'vZLZtH5hnKo',
#   'X3DmlFkC2cI',
#   'ShcnNkr_PEY',
#   'UBuVR8_Mybw',
#   'h0BSqrfXBjM',
#   'dP5Au3tH448',
#   'AqkBD2FK7KE',
#   '-tuHrt42WnI',
#   '9TWB32376QA',
#   'fgK-bxZIG-o',
#   '9E006QLHt0Y',
#   'kEMmKu4tYWI',
#   'K-jYDRd_53w',
#   'XAoQPp9XLt8',
#   'ldS_yHnZMDs',
#   '0NTOZbjg6SE',
#   'YuHD9h5gTS4',
#   'zulLRv0GFhM',
#   'Xc5fFvp8le4',
#   'qv-RVkpQTWs',
#   '1K3iMWgAQzI',
#   'm1fUil7QLNI',
#   '2IIUHleexIk',
#   'cqybfPNbWBA',
#   'E357cGzOGLM',
#   'MQ9GDfE3BZg',
#   'gM_gTtll7FE',
#   '7jrmnPFlqG0',
#   'V-nBAcr_huw',
#   'HALtebWHpNA',
#   'gN-MeB-S8Kw',
#   'nL9Guwuv8HY',
#   'JWv3oRaZO9Y',
#   's8Un0XB_8xk',
#   'Nmkab1LUqlg',
#   'LObJOc5u7sY',
#   'q6kIwfEGLO4',
#   'Aq6RRmDExeI',
#   '9HDKRP4nzc0',
#   'cx20nTPZjes',
#   'cqLMQCG5pCs',
#   '91av8wCH7CI',
#   'xpc07Lbgrow',
#   'orPHNS-0CZI',
#   'VDiOv9148gc',
#   'XtLpZLM4jg0',
#   '5Nnu5Vdhwfs',
#   '9sTVbeq21dI',
#   'GkqI_2Fp9ok',
#   '6RskGkGYtgg',
#   'g0n2zT9xBdM',
#   'TA8JprZlDYA',
#   'VgmyVHYV1mE',
#   'UrzhzCA1NUw',
#   'XZvqQ4xK1R8',
#   'N3NPXB3eiPY',
#   'VTUDzrIgZlI',
#   '4CJvasYJP6o',
#   'dPL1-8ypnEs',
#   'Qfd8nck5cP4',
#   'Ws9KAQS02Yo',
#   'lpwa5iYOjU8',
#   'WjUebpBA2AE',
#   'Mhvv2-iCKao',
#   '4Q6kdHSWNZM',
#   '5x6DELO6Sz4',
#   'sBO5RKq8PXc',
#   'JDJDeuJbiKc',
#   'i4Zt3JZejbg',
#   '8syPkiANwYk',
#   'ZrZISyPucMg',
#   'GttoIyB_lEQ',
#   '2ircZoqveuA',
#   'QXF3tUfvuLU',
#   'TtLHiiXyERA',
#   'KrxrzzTUPD8',
#   'UUBDiUy2824',
#   '3yoAj-PRsZ0',
#   'KG9E5LaI8bk',
#   'UJ9Lbao6j-c',
#   'nnODX_VEp2c',
#   'aJinPXrOZYk',
#   '7hXjxLrDf5I',
#   '9nTJlmsa_Bo',
#   't8eKwFESN8s',
#   '_z9q096Lhj0',
#   'dIfLmM0YkXM',
#   'arlvHJnfFKI',
#   '26C_O6hDMjQ',
#   'CjYPLWcgAOE',
#   'Zh2wtbNrlyw',
#   'f6pPIG3EvAs',
#   'vE-P7zzCCsU',
#   'aEDJkbSJKP0',
#   'RoAPTdvgAJg',
#   'lMGggUDolRI',
#   'DqVPbEcWtA0',
#   'W-QoakKxTjg',
#   '7h-R73VTXXQ',
#   'YyrUBJQmUGs',
#   'pEDQ1z1-PvU',
#   'hoQKLOrAU4E',
#   'Wwp9eaVVW_8',
#   'opVgMDtBecA',
#   'iTLp2F4dm4I',
#   '61TAqY03xwk',
#   'wspZXjeWWq4',
#   'SlTvgY9PeCQ',
#   '3kYDVzwcwcg',
#   's3QcOSyD38M',
#   'XSf33i8njNU',
#   'BK3YvlOFRTg',
#   'X8DOUSGGw10',
#   'nxM-rac7vb4',
#   'uALVIcQXH4Q',
#   '8tU-0Uxz6jw',
#   'ZsxQxS0AdBY',
#   'EC00YntB7LQ',
#   'PNp2IjVv3HI',
#   '9HtGhNUtW-E',
#   'sFGEBTdK2Z0',
#   '2z9uOm-Ydrk',
#   'RUC_F0OQdDg',
#   '5BRVHKG_hpU',
#   'hgj1x0ecJMo',
#   'b7ANcWQEUI8',
#   '5R0_FJ4r73s',
#   'W8BfirN9z94',
#   'TmikWdsrz_U',
#   'y9ue7TNpxS0',
#   'U13DF7R-iuw',
#   'yBWNZTYPbzA',
#   '6trOg2IK2Zg',
#   '7QH1qFd24bY',
#   'BOOa1wZhkzY',
#   'yAyR_YHEZ_c',
#   'lXPvnhNcMs0',
#   'Btr8uOU0BkI',
#   'Ij9njxJUyUQ',
#   'd6605kiXmm8',
#   'AVpfhoi_uOM',
#   '2XvDb37qIdg',
#   'FrgGHAab9D8',
#   'NH_7FqSuxkU',
#   'EcMBuRX-EdU',
#   'c4zAPmQZmYA',
#   'R7siKvpvuCM',
#   'jzezFz6CMqg',
#   'Ew5ZzloH4Mg',
#   'QahWCPNALDA',
#   'z8gOX35dAfc',
#   'pwsPZi_JRrA',
#   'pmnLca3FneU',
#   'd7n34bkF-Ew',
#   'zSlt_2X8sPw',
#   'pZiKLNnanWs',
#   'VQW48jzIcjk',
#   'D0mCG1BeZCo',
#   'paENIboxKGI',
#   'lvNrGxpS2jY',
#   'fbwEaql90Ac',
#   'RwnSX-3ncSA',
#   'y5DyEYuvF3o',
#   'fKDuVDZqQ1c',
#   'r5TvTH3GOdc',
#   '8QF3qJ0U5K0',
#   'qauddPrHLqU',
#   'KBXTLLFgDeo',
#   'EtKa0ORwaU0',
#   'dYzlWWa8dCU',
#   'MVyA-T2lNNk',
#   '_ibTYAxssQw',
#   'szd7M-Qi1MI',
#   'tYGg1fIfuOY',
#   'BldsuTqsI1g',
#   'YGziBcgP93Y',
#   'M8rSmmLNYUc',
#   'L6RW1KaNuL0',
#   'dYmHFsH6E7g',
#   '8L7d6_ZzyoU',
#   'Rrm4isCQDkQ',
#   '8f7mFHYjBG0',
#   'BZjIsZwgKfo',
#   'E0_JrUNevdc',
#   'lVPAfntOfmc',
#   'tTfaaqXYXxQ',
#   'KFD0Nm2dOHw',
#   'kpqBNn_BfKE',
#   '3GrIWdORHvc',
#   'pMFLeoDx6J4',
#   '3AbWtn1ixVk',
#   'Z-W66HINFLg',
#   'tTxhneVcmEo',
#   'Hr8E-_yU2YA',
#   '1dg2UIzIt4s',
#   'RBCaAq_pKjY',
#   '1JEXDBWehvI',
#   'f7TD3Z03l2I',
#   'skXwTxo0Bo0',
#   'P4Hbn6xcD9M',
#   'hUgOgMCKXqs',
#   'z6dkNLn9br0',
#   'OMb-jXlkNwY',
#   'uBEaG6n0XDs',
#   'F0zhwl8454Y',
#   '9NSBB-kFDGQ',
#   'PYJAiY6zuMo',
#   'WBeFfWUdseI',
#   'uQyRDqnr0FM',
#   'IovZRv8toDM',
#   '6Smu8YbwZ9Q',
#   'fsOxwsFF50c',
#   'elXk87IKgCo',
#   '8yKXTr7KB40',
#   'Fi1JUykQBKw',
#   'lEjwyYOFwZg',
#   'h3wKBfAIdzE',
#   'CJTlB_S7ct0',
#   'wEpMtf6nJco',
#   '3ZX8graseUQ',
#   'wwXA27TWD3k',
#   'TK4u6wm-HIk',
#   'nei16gkVxpg',
#   'YmuOwOb35qs',
#   'TTWJq2MpCx4',
#   'fNt-QXLp6YI',
#   'CntfUc_Sd1c',
#   'tC1LxFS5uA4',
#   'saoiKoNvnn8',
#   'epLszn-rnpA',
#   'zb5Wp_i8oQo',
#   '4i3oKEg6o9g',
#   'QrM25jqhXdA',
#   'WxWLVwBqAOc',
#   'H9HH0vqb4q8',
#   'yR0ZGltMUTM',
#   'BygqMgC3W10',
#   'aYtAdCDOCfU',
#   'Cdbn_pmxFic',
#   'onldzSzdqlM',
#   'c74d5kqSEvo',
#   'ZWKl-FeUApA',
#   'jpiPzgBJU9M',
#   'KF75-HPdUfY',
#   'wXmzpFoHkfA',
#   '_bozaSWsDuE',
#   'rIRpK7KAfM0',
#   'swXI_sl5m3I',
#   'jZoh_QKnGbc',
#   'T88kUY9Q3es',
#   '1gUQhN5joSQ',
#   'LDBWrSENTps',
#   'Py6g_FheJWI',
#   'ul3lgaU_lbY',
#   'o9PT9HDXZWs',
#   'zUtedhbQDP4',
#   'PGXhG82HRX0',
#   'GlhXpHULwys',
#   'qp5il7yhM4Y',
#   '6d0lEMp8Vtk',
#   '83Y31z3ZI2A',
#   'CP5LB1eQff0',
#   'xU2fB0pQJkA',
#   'LkOC0gbNF20',
#   'MQ97Kymd6X0',
#   'uj0S2rgmu-M',
#   'XkqiFOvF8v0',
#   '6A-PpwfM1wo',
#   'Wm4jH01Sluc',
#   'N4fpYnzqHEM',
#   'Rd89JLYsoOI',
#   'K9CNsBCmrNg',
#   'mVLyd9_czWE',
#   '9qf3OmxwmhM',
#   'NSWOvw5N4nU',
#   'HVL6Kwk8IOA',
#   'SEXiPc3q1tg',
#   'tRyEYlvb66I',
#   'YginQUkrJ50',
#   'PAs6yQUCkno',
#   '8gca3uud87c',
#   '6PEmKUBtWlk',
#   'iwaW6HR9dw4',
#   'NyoM_i1jJZc',
#   'gfPNNdY1Fjs',
#   'FFuePFTf9LQ',
#   'uO0Q7SMZvfg',
#   'q1zZ8cGF1OI',
#   'IysmRC4aAFc',
#   'xVlzDdxaaaE',
#   'zFOnOLXrMBQ',
#   'bJOGQ_SJ8Dc',
#   'RvfjuYUe6-w',
#   'yRaIjn6q9Jo',
#   'nCVygTgQKUs',
#   'G43tYXIlUV4',
#   'RQy0NeVnxLo',
#   'Tqm8Izfn_oU',
#   'WeHC3qjt1Ws',
#   '7Tw9Yk-6jkQ',
#   'PPEpTasDz2s',
#   'y2d2tlnNYOg',
#   '2No-AEasdz8',
#   'GFdzwQw4CxQ',
#   'VdsMwGWvhO4',
#   'eFcpRIwPqRc',
#   'JpsTUT4F3BA',
#   '-gqjCVTXBeM',
#   'C-b9hmerTac',
#   'hKvoHRAYyMc',
#   'kRB1-APKUqs',
#   '1E6PDgIwFg4',
#   'aSZ2GogKawQ',
#   'Teyx-jx2Ano',
#   'MS3VXAUZcJE',
#   'APQqX8Xd5TA',
#   'IT73da-C4sw',
#   '3L27XnwKWkY',
#   '_02K6efDLI0',
#   '_hhEz4Uo79k',
#   'b_xRPA0CjJg',
#   'YddnWW_JYiY',
#   'bK959V_9XgQ',
#   'ddI-ZZwFclc',
#   'eG0As9lWP7I',
#   'nzikcaYKOkY',
#   'K7uLph0s6f0',
#   'kw-RzN4xYyE',
#   'poSFV9_abcw',
#   '4nKRZA4HVQg',
#   '4JEZ2rrf2N4',
#   'xAT0EmZc-LE',
#   'CultO7cPnJA',
#   ...],
#  ['nhOnLlshf60',
#   'QEo7b36mOcM',
#   'BnXRS18K7gc',
#   'fu_M9EmP_gk',
#   'J_0teOgTAhQ',
#   'YOSQIUGGdYE',
#   'GK6WCUnhUg0',
#   'IqHO9k0fcZo',
#   'gqYaqBVT5vM',
#   'fKoDe6kw_ZE',
#   'krnZUfixffY',
#   'OsQymqWRu6Y',
#   'uWzwovY9u-E',
#   'SNjlnEIGtfw',
#   '_3-rscgRsYM',
#   'duj4CvXimQU',
#   'Aao-RX5DZcA',
#   '1WIFY7_TZUE',
#   'lWqlDixckSI',
#   '6fPj6mj-M_k',
#   'LkYB931iUjc',
#   'NSVUw3KF5PE',
#   'WMGrMWybnrw',
#   'jFGhvYLbBRE',
#   'sJ2x2JVCh1Q',
#   'pmCQtrKBALU',
#   '8_v2SA5uLbc',
#   'pDQGqipmuFA',
#   'zxcvwuaXC_w',
#   'JexvBG9J6qA',
#   'S5iXvDAwNVI',
#   'rHA87rBVkk8',
#   '3kLr60XFr90',
#   'Gw6taLNMIXI',
#   'VjiLBhmiMMw',
#   'VHUF8A2vpos',
#   't3MAu9WxPAE',
#   'PdBTkgtnTsw',
#   'oDwY5N0Bk_w',
#   '3mTV1TOblbA',
#   '1uDfnHoPq3w',
#   'P6mrmEtmBhE',
#   'A0qJahE3y7I',
#   'gVqy_RWtae8',
#   'p2PpqZeMkSs',
#   'SQAfcJ_BHyE',
#   'uUR8V4oBCvA',
#   'IhqCC70ZfDM',
#   '1onnyw9ZMkY',
#   'BH0NbsjeIVQ',
#   'HStRHwwb8Vo',
#   '_ofku--J9ps',
#   '82nGC_uNdqQ',
#   'VAj7jiRtG-A',
#   '7pzlQ69QslQ',
#   '09tZRhiWi-0',
#   'bE75-erVKP0',
#   'ECMcAkbsOEM',
#   'YnRIEXP85k8',
#   'x-Fs-wAmbRY',
#   'PMRZWAVyerM',
#   'jZGhwdeHFSs',
#   'dqX9g7AaqhM',
#   'jmgBwMHpP1w',
#   '5-q55JsyVrc',
#   'TAavlpk2Uuk',
#   '0i_XWYKfIdY',
#   'Xhc3Rq_HZYE',
#   'JKx9P1F8pww',
#   '-zTNuxUl5lM',
#   'UcCl5xG9w7Y',
#   'JLXvC_zykVo',
#   'otGEEanj7gA',
#   '-S5_MQH9jDA',
#   'TMFEEOjQ0tA',
#   'NyhsWXCrToc',
#   'HEZKVkl89zk',
#   'iQyIRvy0rko',
#   'yduMkPn1Vfc',
#   'e5AQNDOP1nA',
#   '3WuxHYFFZ-E',
#   '_e7JTaPMf7Q',
#   'OY2jMXKVhIw',
#   'o54aKk5LZdM',
#   '0WH3itALMrw',
#   'DAYwEhoGJDA',
#   'E59xZyDFiJ8',
#   'tZezzz6tY3o',
#   '651JOj-E1qo',
#   'FKDdeJSyRTw',
#   'GCNbuehl1gg',
#   '2CcBqXzxhFg',
#   'BruI_wB2PSE',
#   '8Uv-ffvBXOg',
#   'MnQXRfCo7aU',
#   'fGtO7oE1Bhk',
#   'WKN9nvXTGHE',
#   '1ZdO8jT5TaY',
#   'teupd0VBGCc',
#   'l3daDnnz-2o',
#   'XeXt1T3p8UI',
#   'DU3OcUvivyo',
#   'lh-ujKV8qcA',
#   'HuB4fd73G_8',
#   'hFVXBUZlQyY',
#   'ztTY788z9NE',
#   'biQbRjeaoHw',
#   '5-lNLNfKr3s',
#   'KuoHW5EiJdQ',
#   'eA95G-sc-TU',
#   '3iLT6iDu8Ds',
#   'iWh1gEKqL7g',
#   'TQdRipT1L28',
#   'LcLi8W0Ysmc',
#   'qhQzCayvfZ8',
#   '-XHPGGE8-Uo',
#   'QhGXjJSg2jA',
#   '_o-D-bgXAKM',
#   'CD8Z_YQkV1o',
#   'ZfgNiVjKAzc',
#   'HLhG8U6ziqs',
#   'YHZp6b8qJew',
#   'aDWgr7YEdTA',
#   '16ayIgVCb5c',
#   'rfYydagxcJI',
#   'QY7lHH521SE',
#   'U7HxYOaFr88',
#   'r7svkjbsnK8',
#   'l5DLz7Ms11g',
#   'VCf6PX0PKNE',
#   'XQ6vX6nmboU',
#   'l2qgTyTVUgI',
#   'Gby4KOzzEEg',
#   'zHwi3Yq6tZM',
#   '7yjea4JxBX8',
#   'qXPiKA5zgT0',
#   'tIqlu4sm5OQ',
#   'Mya3ZvVRTRg',
#   'ybt03airuTk',
#   '0FnX1ufiMzM',
#   'ig5t1nU-mxk',
#   'MfIYLXMhUl8',
#   'Squ0ZCwQga0',
#   'Cp9UoJxW89U',
#   'cFyka8Vp62Y',
#   'V3fSJPlAjAo',
#   'bp6m0L--zSE',
#   'DJDBe5s59b0',
#   'EUJ8333SN3s',
#   'jgLOfZaV3Ac',
#   'pjdcUqJNk5c',
#   '2vaVH0SJa3s',
#   'HybxSfUtvgY',
#   'Luq2IdQvwWc',
#   '-1WdsHDEdUk',
#   'jsumNIdzAZs',
#   'haMV_nkkYsA',
#   'gU3iuGqx5Wg',
#   'S0S6kni_Ff0',
#   '9mRxyH0RWuQ',
#   'IyYgnx80qkY',
#   'EMFCVvy0rkE',
#   'ktoZIF3AN9E',
#   'cwTlJYVNorI',
#   'uNSyXJte4TU',
#   'oAy9EuBRCpg',
#   't7sOFoS-IRk',
#   'rHUnrPy7N6A',
#   '0QLu9gMhQNQ',
#   'AKFRDiI3oEE',
#   'weU1pYsMnRk',
#   'kkvzHjuZAb8',
#   'gzaiCR-o5Hk',
#   'j3T_imAj6uI',
#   'R2yNky1CM3c',
#   'F1uT_oT5aow',
#   'q2KjrPT8u8c',
#   'YyBYHNjQgrQ',
#   'PG6jxXgrOh0',
#   'xSsd-6xjHfw',
#   '5_C8oa8zkAE',
#   'tagUtlYFhJQ',
#   'xSP8u4iiLEg',
#   'DAxSM8yPs1k',
#   '9h6AAqd4Lno',
#   'ynyKcAvvQ1w',
#   'MJcRy2Q6nYU',
#   'vidX3RZQXBI',
#   'XyRUWM_LOPQ',
#   'xDmRpcQQPUo',
#   '-hSOuK7qBgM',
#   'C8sS1rRMXII',
#   'Maz7qkLzwYw',
#   'HS2F8NWV4cQ',
#   'qdqJfFkQKEI',
#   'yN1FJCkwWf0',
#   'ElRn6AX9IBs',
#   'lojuls2PmYs',
#   'JwX4gQzudYM',
#   'NaSGsrHiK88',
#   'qTO7959ySss',
#   'h-ronBX8pxA',
#   'dcszY8OP-zw',
#   'NLyZHFTNGfw',
#   'UlN8xu5ooYo',
#   'qlbAQArT7YQ',
#   '2SfSUjxNHtE',
#   'YVpQ4xV_VB0',
#   'gLO7643fT1E',
#   'tFsLpLOEUIk',
#   'v5PEXWv--G8',
#   'YF3P2-I8bVc',
#   'C5SSsle77oY',
#   'UaK5xguzD_A',
#   'rHwbgza_QJE',
#   'qyuyKwMujCY',
#   '8zdJ9qUZxUo',
#   'khXwVtzhraI',
#   '_v5IzvVTw7A',
#   'ZJ6hc9Scd3s',
#   'cHxOBS97fDU',
#   'bp65vZEzIuo',
#   'OG5-MVpkQjg',
#   'MPnzBxCmBKk',
#   '10tXmE1IXw0',
#   'A7hgf-RfHyc',
#   'WTr5o0Axkpc',
#   'wQjxHfLfdy0',
#   '65EY5fbwJCY',
#   'TQ8SpKaXkWg',
#   '6oTCwTLV-Kw',
#   'R9MamtGWl9E',
#   'FEkYd1qF5Ko',
#   'ByCDKBBhdZg',
#   'i0k3JPFtw60',
#   'xniDjNQtqyg',
#   'PDdNGsqi1Ho',
#   '3F0WDu0_tn0',
#   'DhgPCAvRW7Y',
#   'tKxHJixw87s',
#   'HEZqanWT27w',
#   'NYl97rTsevQ',
#   '68uhLlX6BJI',
#   'Nt8UWWqa7uM',
#   'KbuCQqV_ULI',
#   '25eFzFXcdyA',
#   'vcYlYRRHsCI',
#   'uDqmLrpMz7A',
#   'RzGCFDYKQM0',
#   '5GhCaAkWuSo',
#   '8MkyTIU_ZLk',
#   'GzXiDhd6loM',
#   'TL1LLfmtD0w',
#   'vzB-rxPF6cw',
#   'YlkFUB_XLVs',
#   'PpGk15i6eTc',
#   'iJvr0VPsn-s',
#   '5kFEg2fRxA4',
#   'cdt5mIzIFco',
#   'BiFgSAcn_ls',
#   'l0HmxGNQ_ao',
#   'ENJwA9MVHz8',
#   '92vWhjZmNbg',
#   'ouiOZsIatGQ',
#   'uDEIyjm-Uls',
#   'QBHws9hPJYs',
#   '1CEDr7VvNaw',
#   'TktssLcTt7Q',
#   'phDTqsgU5kA',
#   'YyMiZCXRMQY',
#   'rNKMrEcrNZQ',
#   'K7pEmHo1CkQ',
#   'sMib1nMCdfc',
#   'N4zVExS5mgg',
#   'NLfAQQlSOwc',
#   'wNLbP45aTO8',
#   'b6-qoXEYY10',
#   '-zZYVCeoOeA',
#   '8wSYgT9shSY',
#   'n95wxMxz_us',
#   'y5LTnJI2Nm0',
#   '9Cor70qmThU',
#   'jPFiDIYUUxo',
#   'HdUAEYqK5tE',
#   'cYsNQF20b5I',
#   'desL7v-gBUk',
#   'z8AdxtkkQDo',
#   'Ov3Nq1WkUMI',
#   'LPJHd9asM7w',
#   'otHviixLykI',
#   'G0inmw5q6kk',
#   'pdUKug8XahU',
#   'fJATz_Mu2Wg',
#   'Hz2AUON5jmY',
#   'PfgMdGWVyiQ',
#   'TNR3xPNxzgM',
#   'U-SPrjbeElU',
#   'yjrmjarfzmI',
#   'FqoxQaFG_9c',
#   'W15yKKbHE80',
#   'Mmlv3ksJ2BA',
#   'HfnQfO9p5EE',
#   'h22xb2x0sTc',
#   'pAEVLUeYaf8',
#   'pXkE0BlTBmI',
#   '0FQ6WGJkLPs',
#   'bTUytmEYx6s',
#   '0yfF0Mri_t8',
#   'iqv7btFcIFo',
#   'DFjKYBa6ZqU',
#   'we2I6pd3KlI',
#   'WxRblujlYOg',
#   '6bLG0GcCYik',
#   'S5-12O3kiho',
#   'xu6-yuDVp1Y',
#   '6022e03wp2E',
#   'mykA0jrZWF0',
#   's1C2cNdAzI0',
#   'lzAhPhA3JGE',
#   '-GPgoiq-rdE',
#   'Y7zS-ZICkWk',
#   '1bEoAI5DMrA',
#   'OiKQpnWndOg',
#   'inPgVEy6ojg',
#   '2_azRm5CQ7g',
#   'rKcWT1LIH3M',
#   'Kp1vy6fBhPM',
#   'oY9e59FS7Tw',
#   'ohbpuBO6-9Q',
#   'IsgNhhlIUrU',
#   'NhmwRxwwSTA',
#   '3PtbK_0j1sw',
#   'PIoJeY0rx-w',
#   '3mQh7mFgeBc',
#   'G7LVgdfCNOw',
#   'UdQxMux_cu0',
#   'CQtpiBqVQyY',
#   '0xT_2jfVaII',
#   'Aj6vXhN-g6k',
#   'tcUQG0MC_OQ',
#   'idjy3AUmozY',
#   '96ZKECaj180',
#   'tSRfYteappo',
#   '8DULIfYDyBo',
#   '0tx3nmA2pSM',
#   'pBfkVKvQrcU',
#   'nGplsMkStVM',
#   'HQgdLvSlQdc',
#   'mtDQTKqidXY',
#   'JE_Ja_6nlbg',
#   'BUisXF5_TCU',
#   'S7900rTHdCo',
#   'lTTOaXffYZc',
#   'BXMBvKPRsEo',
#   'wUwVfaJfnBE',
#   '33THbvTODdM',
#   'qg5HeTGSv3I',
#   'tJW0ZYxQqgs',
#   'A2bSYFJ73oE',
#   'ADEh9F0Lidc',
#   '2oWw8pwXlZA',
#   'TAt2EMsszuk',
#   'ZdwtnZUUOWo',
#   'HubbDiz0nsc',
#   'sc69B9b-TVw',
#   'BJRccu6aXHM',
#   '71-Ji7OtriY',
#   'UKEVljWNaA8',
#   'STqRlcuZbHs',
#   'DFEi8gKMqIM',
#   '7gwBxKHBoEI',
#   'GJLlxj_dtq8',
#   '-CVqAVX5aAc',
#   'KrKws3D3ZDw',
#   'UTguywiC9aw',
#   'xeUlGnNUut8',
#   'Dx8J125s4cg',
#   '18PA3WFFuAo',
#   'VTSwlRFyFlw',
#   'emHyQNfQKaw',
#   'mdRpgWYWCZg',
#   'QrK7pGmwlNY',
#   'gLQTKwY-vJI',
#   'vpAiZBrzQdM',
#   'y_Vx3kt3NUw',
#   'UQaHNS7oCWY',
#   'NYRsJnViBgs',
#   '0pO7DWIfR6Y',
#   'g6QZcvqyE-Y',
#   'MCDEY2MFnF8',
#   'b5wGGp88nBs',
#   'aXjIz-vH3oY',
#   '9lzvoBCOlJM',
#   'H-gQLLUU5fM',
#   'WY7-Q6JKijs',
#   '5qXUy5EQb1c',
#   'WMg8SJJEC2I',
#   's8aCPlUhXTg',
#   'gE92XtxCnyg',
#   '7O40VobH7NU',
#   'WbGaqJehEHw',
#   'MzaQrNUrXoY',
#   'TvXBl063ixk',
#   'dgFday9MrmA',
#   'zQT8rMlqfqI',
#   'iTZlYpaOZfw',
#   'yEV9MGrxbEU',
#   'E_2ptII-7DY',
#   '-DbCq7FRSDc',
#   'EavSblb031o',
#   'hpJ6Tzoz-ZY',
#   'ajTUqSXzZis',
#   'ujws3_SLMPk',
#   'KWBjfoioS20',
#   'pJqbhRRZx8w',
#   'cyJ7aWLWSSM',
#   'RtmHCT8WQRI',
#   '9AIJpbokB80',
#   'vLAucnrFDOQ',
#   'ZPNgL1Ss7fU',
#   'HQgZh-eGESw',
#   'p-W5W_KIsUw',
#   'NM3u-0eKVFE',
#   'nPFYvVuqZLI',
#   'GWRwuilpbGw',
#   'C-gwT7sI8SU',
#   'S6fjNq0PGYo',
#   'KRSSXwLVgao',
#   'v2-ytP-HllE',
#   'U0BjO3Z-CXM',
#   'GGt4yJL09IU',
#   'HbNYuOTaYFs',
#   'egaGs_mFQns',
#   '22OcG-OAdQw',
#   'Syar32OLFNE',
#   'HPfjKPzitIQ',
#   'M-NRyniYjeE',
#   'gilkylyKIpg',
#   'ulrFWWk9UM8',
#   'ZIDYBeJ-UKE',
#   'CBZHavTlT6w',
#   '85_fSnZ6NUM',
#   'WdYBSJyxtdo',
#   'RARKNr6ru-c',
#   'GDtkEbxY_6k',
#   '9L0ENfK9wvM',
#   '2RQLoqTnQJo',
#   'axSIWl_pMrI',
#   'FopoTlnNRRs',
#   '-VLKdC8awMk',
#   'fsGEkCw_B70',
#   'fJEFIQSdsqw',
#   'EDecUtVfKmU',
#   'rPUccVeV4I0',
#   'IKAKcgYIHWY',
#   'ZBePB1Um7FM',
#   'aiYZZmEdXlQ',
#   'bi2WfEI5V7Y',
#   'tAi2tkbsaxA',
#   '1Rv6h55ZDiE',
#   'mJ22d23rCXA',
#   'f2rfwR-IV-c',
#   'Dq3PhCK7cn4',
#   'gwQeXeJuuyQ',
#   'efkQrXv4ckc',
#   'ZADtgM56wvE',
#   'gTDResMIK_w',
#   'JxQ-9pXoIJM',
#   'ydzC7jb5C4s',
#   'qPR27T-1vag',
#   'XhEOpqwZeNQ',
#   'MDapV6EE2_w',
#   'mTS7juj9N1E',
#   'KCRRYzan7BU',
#   'vv1W0C920oE',
#   'EKUn7MpfQMg',
#   'sSgqyd2Mcdc',
#   'KNbWi-KzAik',
#   'XW5Z4Vsda7U',
#   'SKFlz4to3ks',
#   '_3JZRxVPuew',
#   'ZXrc1wNS0L8',
#   'L9Jqnyt__Ps',
#   'zHaPSrpyYlE',
#   'tNCwvihWO78',
#   'kUDjt4gjMO4',
#   'R_8BsUZIHgc',
#   'al_5-BDDFPs',
#   'ImO-vBmL4gk',
#   'd6VJSZsKN0Y',
#   '-DaDjFm7_qw',
#   'EIc6v4C0_-w',
#   'im0FA2X6fp0',
#   'rXQJTW6uBq4',
#   '1pqioE3jqwg',
#   'aHKqhRjRkbE',
#   'No5RbW1A2Ss',
#   'vsi3xRXryUA',
#   'YcPm16U55sE',
#   'pX56Sj4XzGM',
#   'F0ZOqg8JjsE',
#   'Laz6NL55FD4',
#   'uH0UQl5JC2c',
#   'c4ikwbO_rho',
#   'oQgaEL8gn3Q',
#   '6ysFDaHpMfg',
#   'xkzh7mfY1ik',
#   'WBAzdNdCVxw',
#   'e_aSht_ssls',
#   'fURkRSbO20k',
#   'ddDvm7C1RMo',
#   'wQBtzNCuCAA',
#   '6tpe_6ILN5k',
#   'qxwMlYMMSnI',
#   'k_GM1JA608Y',
#   'CAZ0aH-hiUU',
#   'DRVQqndA7rA',
#   'a59U6kRJHLg',
#   'eg3u-rRjYF8',
#   '4vY0NqKNmB4',
#   'wtSlhqHolso',
#   'BSMOp8nBKes',
#   'rvhH0DW85DA',
#   'Gb7a9Alm_ZM',
#   'f-dH7_WUwI8',
#   'O82mvIMBzPg',
#   'QBNP5I2y668',
#   'DDZW6ZUESzg',
#   'Tf3095vIE1I',
#   '0siMCwXf6-E',
#   'xlBmdFORhZ8',
#   'jTMRestOZ3I',
#   'wAiH6rdr78Q',
#   'wEb0mWN5-gE',
#   'ZQFn1Z-x9DQ',
#   'EnhtpjbNHWY',
#   'aZ_0mh9Z4AQ',
#   'FSmXA01l-_8',
#   'mVV2fF352qk',
#   'iKkIrd-OMvM',
#   'vvAB3U5umug',
#   'NLsDn59fxdQ',
#   'Ws7S5lXw7zk',
#   'CCQ8NJUz2Ss',
#   '6EzMVumwxqI',
#   'ZH0hBJTpEkI',
#   'l8ZGbxskrVE',
#   'ibVhqq9Asqw',
#   'zhhxK83hWzU',
#   'G_VUD7r0gVA',
#   'gDPs9o_L1GI',
#   'niExdgR14Gk',
#   'ac9ogKirkGQ',
#   'Dtjllca-AaQ',
#   'ZZDUJeUhX9c',
#   'fiYNaTeRYC8',
#   '_i83H3FDGw8',
#   'e2ZanubcQjE',
#   'rRmwJVXo16Y',
#   'y62POiaRbtU',
#   'diRhFErwN_g',
#   'TTTGiUi9Jfw',
#   'dRm8g7Y0plM',
#   'Ymnv_h4763A',
#   'GXRLOEeSC9Q',
#   'A6ijaVcLWE0',
#   'icQMelb7mKY',
#   '2Ohf1owHuQ8',
#   'VftseA5k7Zk',
#   'UEDLieBoTsI',
#   'lvkZRMPM8aQ',
#   'IDJd_9CMkEg',
#   'jW0a3UikQqk',
#   'WSnT2UHrpEk',
#   'rH7SoJUpnNA',
#   'TEFIF8dX3yU',
#   '7LB7OA_2dgI',
#   'rGLDGoG0DJU',
#   'OCWRdrpQ83w',
#   'Ke162NPmBbE',
#   '1eJYl5y6q6M',
#   '_ze5p_hG6wY',
#   'Dvzle0olkj0',
#   'w2BdiAbz6iA',
#   'KHrJ9IA60MI',
#   'e6DuYZeVx2M',
#   'BOFZGCwoRmo',
#   '_XLTaK5oz3c',
#   'TN-Rub-lmc4',
#   'chgG_9rmDgg',
#   'f-iD0YrkFfI',
#   'RsxhcTs0zJ8',
#   '7MmN30IixrQ',
#   'jRWJeKbhMK8',
#   'P33QHwPqdWM',
#   'E5hZb7Eo-2g',
#   '6TcoAnk_Q-c',
#   'oEIGX1MTh-M',
#   's0mXMTjZy5M',
#   'lvsPxoldsic',
#   'hJZM6i32MZ0',
#   '2rCKUcaS198',
#   'dolFOVPUp-4',
#   'dYC9OpV_PvI',
#   'FkmisXljv8w',
#   'XODqm66ooMQ',
#   '_kYgiPN-bJU',
#   'I4SgcraOAOU',
#   '5Xby_KZmHsw',
#   'XDtTvAkKT4g',
#   'wn8SpOoY_aw',
#   '2K3mrnkSHxw',
#   '31ZIhan9eu8',
#   'TXUOB9EuUIc',
#   'uWUztGO5puE',
#   'ZRmRamdNFHg',
#   'pcbfAuehGsc',
#   'hCl7IR16U7A',
#   'xyGnAMxhXGA',
#   '8eWGcKR3ho4',
#   'r_8yFIYxP4s',
#   '9-603kcKyMI',
#   'qA-8_OpUdEM',
#   'BYdntBKpJnw',
#   'i_HzXNRI1DE',
#   'e7IH8MjUuUo',
#   '57ISNozMfYk',
#   '4m4GqChBz4Q',
#   'keziN-DEK6M',
#   'vyNrgSue3E4',
#   'VWbYR1z467Y',
#   'XzQPkDk07FM',
#   'K0wpV0xRKXg',
#   'jWTbZLPoYKc',
#   '0BwVW2-G0EU',
#   '9BUdJhjWTH0',
#   '9F1k53y4Rf8',
#   'Gqubax7O1bY',
#   '5Ay1RLg9_Pk',
#   'OxSkQLHcjcE',
#   '3C18M-bsmxY',
#   'BpxZED9IMi8',
#   'oMN7ycsXfCo',
#   'aUGbl-Rced0',
#   '5H6d4MA-6X8',
#   'bMOtP68xR6g',
#   'mH_swkTcsFw',
#   'XFQ4La8te1M',
#   'ULd_sxplvf4',
#   'KW2Xk8fksfM',
#   '9kxeOShI5Dc',
#   '0QylvO0d48s',
#   'Z2vlynTXjqA',
#   'OzLxTjwqRjw',
#   '9yFrMgEerAs',
#   'mDPjqf33m8k',
#   'aiA0wWKXIPo',
#   '8acCb5O1Uyc',
#   'jlLxtG__HTw',
#   'W3VDcUP60sE',
#   'zlIMsqn1etk',
#   'HvAOiZEJI-k',
#   'BnUyVt-IgBI',
#   'zwOcWuAbuxs',
#   'UULEkS-oOaE',
#   '0JBz0W6KW04',
#   'KXjbppME-hg',
#   'G5vZfGxNSzA',
#   'QtUCtOu0-Bs',
#   'Yk1CGk0TZAw',
#   'qWl7vdTFJqM',
#   'aRQHvynk7IA',
#   '7PCj7_buAik',
#   '5P5QwVlB2kg',
#   'XnFh3s74Dxg',
#   'qL4vZjhwJsk',
#   '0NOcojVOgeI',
#   'e_r_qNy7bno']]

# %%
import itertools

all_video_list = list(itertools.from_iterable(all_video_list))

all_video_list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [28], in <cell line: 3>()
#       1 import itertools
# ----> 3 all_video_list = list(itertools.from_iterable(all_video_list))
#       5 all_video_list
#
# AttributeError: module 'itertools' has no attribute 'from_iterable'

# %%
"""
>>> x = [["a","b"], ["c"]]
>>> [inner
...     for outer in x
...         for inner in outer]
['a', 'b', 'c']

>>> [j for i in x for j in i]
['a', 'b', 'c']

"""
all_video_list = []
for outer in all_videos:
    for inner in outer:
        all_video_list = list(inner)

# %%
all_video_list
# Out:
# ['e', '_', 'r', '_', 'q', 'N', 'y', '7', 'b', 'n', 'o']

# %%
get_video_stats(youtube_builder, all_videos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 get_video_stats(youtube_builder, all_videos)
#
# Input In [16], in get_video_stats(youtube, video_ids)
#      94 all_video_tag = []
#      95 for i in range(0, len(video_ids), 50):
#      96     requests = youtube_builder.videos().list(
#      97         part = 'snippet, statistics',
# ---> 98         id = ','.join(video_ids[i:i+50])
#      99     )
#     100     response = requests.execute()
#     101     for video in response['items']:
#
# TypeError: sequence item 0: expected str instance, list found
