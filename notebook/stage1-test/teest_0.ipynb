# %%
import json
import pandas as pd 
import numpy as np

file = '/Users/chouwilliam/OrbitNext/api-data-download/disney_uk.json'
data = None
with open(file, 'r') as f:
    data = json.load(f)

channel_id, stats = data.popitem()
# print(stats)
print(channel_id)
channel_stats = stats['channel_stats']
video_stats = stats['video_data']
# Out:
# UCMUnInmOkrWN4gof9KlhNmQ

# %%
# channel statistics

channel_stats['viewCount']
channel_stats['subscriberCount']
channel_stats['videoCount']

print('viewCount',channel_stats['viewCount'])
print('subscriberCount',channel_stats['subscriberCount'])
print('videoCount',channel_stats['videoCount'])
# Out:
# viewCount 1349914280
# subscriberCount 5010000
# videoCount 249

# %%
print(video_stats)
# Out:
# {'4rgXPII6ZLc': {'publishedAt': '2022-08-16T05:47:33Z', 'channelId': 'UCNQ26rIaKOiHF-yf8DgvBfQ', 'title': 'Islamic countries on India : Independence Day पर Muslim देश भारत से ये बोले, France ने जीता दिल', 'description': 'Original Video :- https://youtu.be/OCyFbi-XZPY\n\n\n\nPlzzz subscribe like share and comment on our videos its keep us motivated thanku so much\n\nI will give credit to the guy/girl who make this beautiful video  \n                      \nif u guys have anykind of copyright problems u can mail us 👇\n     Mubashirktk4@gmail.com\n     we will remove our video thanks ❤\n     \n               .......  ......  ..Instagram............\n     Mubashir:- Mubashirktk007\n     Muddasser:- muddasser5\n\nthanks for everything peace 🇮🇳🇵🇰', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4rgXPII6ZLc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/4rgXPII6ZLc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg
# ...

# %%
# video statistics

sort_videos = sorted(video_stats.items(), key=lambda item: int(item[1]["viewCount"]), reverse=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/r5/gtzqcf650_g0lkph3ky8hrnh0000gn/T/ipykernel_37417/2501401170.py in <module>
#       1 # video statistics
#       2
# ----> 3 sort_videos = sorted(video_stats.items(), key=lambda item: int(item[1]["viewCount"]), reverse=True)
#
# /var/folders/r5/gtzqcf650_g0lkph3ky8hrnh0000gn/T/ipykernel_37417/2501401170.py in <lambda>(item)
#       1 # video statistics
#       2
# ----> 3 sort_videos = sorted(video_stats.items(), key=lambda item: int(item[1]["viewCount"]), reverse=True)
#
# KeyError: 'viewCount'
